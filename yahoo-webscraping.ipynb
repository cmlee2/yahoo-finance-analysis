# %%
# Import Dependencies

from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Launch the browser
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Visit Website
url = "https://finance.yahoo.com/most-active"
browser.visit(url)

# %%
# Create Beautiful Soup Object
html = browser.html
stock_soup = soup(html, 'html.parser')

# %%
# Extract all the rows of data
table = stock_soup.find('table' , class_ ="W(100%)")
header = table.find_all('th')
stock_data = table.find_all('tr')

# %%
# Save Column Titles (Probably a way to do this within for loop)
column = []

for head in header:
    column.append(head.text.strip())

# %%
# Loop through most active stocks and save data in to a list
stock_list = []
for x in range (0,18):
    html= browser.html
    stock_soup = soup(html, 'html.parser')
    table = stock_soup.find('table' , class_ ="W(100%)")
    stock_data = table.find_all('tr')
    for row in stock_data:
        row_data = []
        for col in row.find_all('td'):
            row_data.append(col.text.strip())
        stock_list.append(row_data)
    if x != 17:
        browser.find_by_css('span[class = "Va(m)"]').last.click()
    
stock_list
# Out:
# [[],
#  ['TSLA',
#   'Tesla, Inc.',
#   '260.54',
#   '+4.64',
#   '+1.81%',
#   '167.916M',
#   '134.541M',
#   '825.782B',
#   '75.08',
#   ''],
#  ['INTC',
#   'Intel Corporation',
#   '36.37',
#   '+0.55',
#   '+1.54%',
#   '110.24M',
#   '45.625M',
#   '151.699B',
#   'N/A',
#   ''],
#  ['SOFI',
#   'SoFi Technologies, Inc.',
#   '8.60',
#   '-0.95',
#   '-9.95%',
#   '107.557M',
#   '49.16M',
#   '8.092B',
#   'N/A',
#   ''],
#  ['AAPL',
#   'Apple Inc.',
#   '184.92',
#   '-1.09',
#   '-0.59%',
#   '101.256M',
#   '58.332M',
#   '2.909T',
#   '31.34',
#   ''],
#  ['RIVN',
#   'Rivian Automotive, Inc.',
#   '14.88',
#   '-0.36',
#   '-2.36%',
#   '92.23M',
#   '25.096M',
#   '13.977B',
#   'N/A',
#   ''],
#  ['PLTR',
#   'Palantir Technologies Inc.',
#   '16.30',
#   '-0.30',
#   '-1.81%',
#   '90.696M',
#   '65.051M',
#   '34.531B',
#   'N/A',
#   ''],
#  ['AMZN',
#   'Amazon.com, Inc.',
#   '125.49',
#   '-1.62',
#   '-1.27%',
#   '84.247M',
#   '62.096M',
#   '1.288T',
#   '306.07',
#   ''],
#  ['AMD',
#   'Advanced Micro Devices, Inc.',
#   '120.08',
#   '-4.16',
#   '-3.35%',
#   '82.007M',
#   '68.773M',
#   '193.372B',
#   '667.11',
#   ''],
#  ['NIO',
#   'NIO Inc.',
#   '9.40',
#   '-0.39',
#   '-3.98%',
#   '81.4M',
#   '50.885M',
#   '16.785B',
#   'N/A',
#   ''],
#  ['DISH',
#   'DISH Network Corporation',
#   '6.47',
#   '+0.23',
#   '+3.69%',
#   '79.289M',
#   '12.497M',
#   '3.446B',
#   '1.91',
#   ''],
#  ['F',
#   'Ford Motor Company',
#   '14.42',
#   '-0.03',
#   '-0.21%',
#   '75.398M',
#   '61.555M',
#   '57.691B',
#   '19.75',
#   ''],
#  ['NVDA',
#   'NVIDIA Corporation',
#   '426.92',
#   '+0.39',
#   '+0.09%',
#   '65.571M',
#   '47.72M',
#   '1.054T',
#   '222.35',
#   ''],
#  ['T',
#   'AT&T Inc.',
#   '16.06',
#   '+0.03',
#   '+0.19%',
#   '64.149M',
#   '38.048M',
#   '114.813B',
#   'N/A',
#   ''],
#  ['PFE',
#   'Pfizer Inc.',
#   '40.06',
#   '+0.31',
#   '+0.78%',
#   '60.339M',
#   '24.457M',
#   '226.151B',
#   '7.90',
#   ''],
#  ['ZI',
#   'ZoomInfo Technologies Inc.',
#   '26.82',
#   '-1.58',
#   '-5.56%',
#   '58.349M',
#   '5.38M',
#   '11.338B',
#   '111.75',
#   ''],
#  ['SIRI',
#   'Sirius XM Holdings Inc.',
#   '3.9400',
#   '+0.1100',
#   '+2.87%',
#   '57.974M',
#   '16.122M',
#   '15.241B',
#   '13.59',
#   ''],
#  ['GOOG',
#   'Alphabet Inc.',
#   '124.06',
#   '-1.73',
#   '-1.38%',
#   '56.699M',
#   '26.554M',
#   '1.571T',
#   '27.63',
#   ''],
#  ['PANW',
#   'Palo Alto Networks, Inc.',
#   '246.53',
#   '+2.73',
#   '+1.12%',
#   '54.823M',
#   '5.098M',
#   '75.402B',
#   '367.96',
#   ''],
#  ['GPK',
#   'Graphic Packaging Holding Company',
#   '26.01',
#   '-0.16',
#   '-0.61%',
#   '53.235M',
#   '3.857M',
#   '7.989B',
#   '12.94',
#   ''],
#  ['BAC',
#   'Bank of America Corporation',
#   '29.19',
#   '-0.18',
#   '-0.61%',
#   '53.05M',
#   '54.199M',
#   '232.619B',
#   '8.77',
#   ''],
#  ['CCL',
#   'Carnival Corporation & plc',
#   '15.80',
#   '-0.32',
#   '-1.99%',
#   '51.112M',
#   '39.122M',
#   '20.585B',
#   'N/A',
#   ''],
#  ['DBX',
#   'Dropbox, Inc.',
#   '25.97',
#   '+0.14',
#   '+0.54%',
#   '47.223M',
#   '4.317M',
#   '9.081B',
#   '16.65',
#   ''],
#  ['MSFT',
#   'Microsoft Corporation',
#   '346.62',
#   '-1.48',
#   '-0.43%',
#   '46.552M',
#   '28.589M',
#   '2.577T',
#   '37.59',
#   ''],
#  ['WBD',
#   'Warner Bros. Discovery, Inc.',
#   '12.80',
#   '-0.33',
#   '-2.51%',
#   '46.121M',
#   '20.288M',
#   '31.182B',
#   'N/A',
#   ''],
#  ['GOOGL',
#   'Alphabet Inc.',
#   '123.53',
#   '-1.56',
#   '-1.25%',
#   '45.536M',
#   '34.295M',
#   '1.572T',
#   '27.76',
#   ''],
#  [],
#  ['TSLA',
#   'Tesla, Inc.',
#   '260.54',
#   '+4.64',
#   '+1.81%',
#   '167.916M',
#   '134.541M',
#   '825.782B',
#   '75.08',
#   ''],
#  ['INTC',
#   'Intel Corporation',
#   '36.37',
#   '+0.55',
#   '+1.54%',
#   '110.24M',
#   '45.625M',
#   '151.699B',
#   'N/A',
#   ''],
#  ['SOFI',
#   'SoFi Technologies, Inc.',
#   '8.60',
#   '-0.95',
#   '-9.95%',
#   '107.557M',
#   '49.16M',
#   '8.092B',
#   'N/A',
#   ''],
#  ['AAPL',
#   'Apple Inc.',
#   '184.92',
#   '-1.09',
#   '-0.59%',
#   '101.256M',
#   '58.332M',
#   '2.909T',
#   '31.34',
#   ''],
#  ['RIVN',
#   'Rivian Automotive, Inc.',
#   '14.88',
#   '-0.36',
#   '-2.36%',
#   '92.23M',
#   '25.096M',
#   '13.977B',
#   'N/A',
#   ''],
#  ['PLTR',
#   'Palantir Technologies Inc.',
#   '16.30',
#   '-0.30',
#   '-1.81%',
#   '90.696M',
#   '65.051M',
#   '34.531B',
#   'N/A',
#   ''],
#  ['AMZN',
#   'Amazon.com, Inc.',
#   '125.49',
#   '-1.62',
#   '-1.27%',
#   '84.247M',
#   '62.096M',
#   '1.288T',
#   '306.07',
#   ''],
#  ['AMD',
#   'Advanced Micro Devices, Inc.',
#   '120.08',
#   '-4.16',
#   '-3.35%',
#   '82.007M',
#   '68.773M',
#   '193.372B',
#   '667.11',
#   ''],
#  ['NIO',
#   'NIO Inc.',
#   '9.40',
#   '-0.39',
#   '-3.98%',
#   '81.4M',
#   '50.885M',
#   '16.785B',
#   'N/A',
#   ''],
#  ['DISH',
#   'DISH Network Corporation',
#   '6.47',
#   '+0.23',
#   '+3.69%',
#   '79.289M',
#   '12.497M',
#   '3.446B',
#   '1.91',
#   ''],
#  ['F',
#   'Ford Motor Company',
#   '14.42',
#   '-0.03',
#   '-0.21%',
#   '75.398M',
#   '61.555M',
#   '57.691B',
#   '19.75',
#   ''],
#  ['NVDA',
#   'NVIDIA Corporation',
#   '426.92',
#   '+0.39',
#   '+0.09%',
#   '65.571M',
#   '47.72M',
#   '1.054T',
#   '222.35',
#   ''],
#  ['T',
#   'AT&T Inc.',
#   '16.06',
#   '+0.03',
#   '+0.19%',
#   '64.149M',
#   '38.048M',
#   '114.813B',
#   'N/A',
#   ''],
#  ['PFE',
#   'Pfizer Inc.',
#   '40.06',
#   '+0.31',
#   '+0.78%',
#   '60.339M',
#   '24.457M',
#   '226.151B',
#   '7.90',
#   ''],
#  ['ZI',
#   'ZoomInfo Technologies Inc.',
#   '26.82',
#   '-1.58',
#   '-5.56%',
#   '58.349M',
#   '5.38M',
#   '11.338B',
#   '111.75',
#   ''],
#  ['SIRI',
#   'Sirius XM Holdings Inc.',
#   '3.9400',
#   '+0.1100',
#   '+2.87%',
#   '57.974M',
#   '16.122M',
#   '15.241B',
#   '13.59',
#   ''],
#  ['GOOG',
#   'Alphabet Inc.',
#   '124.06',
#   '-1.73',
#   '-1.38%',
#   '56.699M',
#   '26.554M',
#   '1.571T',
#   '27.63',
#   ''],
#  ['PANW',
#   'Palo Alto Networks, Inc.',
#   '246.53',
#   '+2.73',
#   '+1.12%',
#   '54.823M',
#   '5.098M',
#   '75.402B',
#   '367.96',
#   ''],
#  ['GPK',
#   'Graphic Packaging Holding Company',
#   '26.01',
#   '-0.16',
#   '-0.61%',
#   '53.235M',
#   '3.857M',
#   '7.989B',
#   '12.94',
#   ''],
#  ['BAC',
#   'Bank of America Corporation',
#   '29.19',
#   '-0.18',
#   '-0.61%',
#   '53.05M',
#   '54.199M',
#   '232.619B',
#   '8.77',
#   ''],
#  ['CCL',
#   'Carnival Corporation & plc',
#   '15.80',
#   '-0.32',
#   '-1.99%',
#   '51.112M',
#   '39.122M',
#   '20.585B',
#   'N/A',
#   ''],
#  ['DBX',
#   'Dropbox, Inc.',
#   '25.97',
#   '+0.14',
#   '+0.54%',
#   '47.223M',
#   '4.317M',
#   '9.081B',
#   '16.65',
#   ''],
#  ['MSFT',
#   'Microsoft Corporation',
#   '346.62',
#   '-1.48',
#   '-0.43%',
#   '46.552M',
#   '28.589M',
#   '2.577T',
#   '37.59',
#   ''],
#  ['WBD',
#   'Warner Bros. Discovery, Inc.',
#   '12.80',
#   '-0.33',
#   '-2.51%',
#   '46.121M',
#   '20.288M',
#   '31.182B',
#   'N/A',
#   ''],
#  ['GOOGL',
#   'Alphabet Inc.',
#   '123.53',
#   '-1.56',
#   '-1.25%',
#   '45.536M',
#   '34.295M',
#   '1.572T',
#   '27.76',
#   ''],
#  [],
#  ['LCID',
#   'Lucid Group, Inc.',
#   '6.48',
#   '-0.11',
#   '-1.67%',
#   '45.154M',
#   '23.409M',
#   '13.01B',
#   'N/A',
#   ''],
#  ['MAC',
#   'The Macerich Company',
#   '11.32',
#   '+0.11',
#   '+0.98%',
#   '44.09M',
#   '2.583M',
#   '2.533B',
#   'N/A',
#   ''],
#  ['OVV',
#   'Ovintiv Inc.',
#   '37.90',
#   '+0.36',
#   '+0.96%',
#   '43.288M',
#   '3.964M',
#   '10.472B',
#   '2.23',
#   ''],
#  ['XOM',
#   'Exxon Mobil Corporation',
#   '105.13',
#   '-0.76',
#   '-0.72%',
#   '43.129M',
#   '15.778M',
#   '425.038B',
#   '7.12',
#   ''],
#  ['META',
#   'Meta Platforms, Inc.',
#   '284.43',
#   '+2.60',
#   '+0.92%',
#   '43.128M',
#   '22.982M',
#   '728.921B',
#   '35.38',
#   ''],
#  ['AI',
#   'C3.ai, Inc.',
#   '44.49',
#   '-1.88',
#   '-4.05%',
#   '41.084M',
#   '29.026M',
#   '5.069B',
#   'N/A',
#   ''],
#  ['GFI',
#   'Gold Fields Limited',
#   '14.98',
#   '-0.14',
#   '-0.93%',
#   '37.902M',
#   '6.079M',
#   '13.483B',
#   '19.21',
#   ''],
#  ['CSCO',
#   'Cisco Systems, Inc.',
#   '52.07',
#   '+0.14',
#   '+0.27%',
#   '37.134M',
#   '19.136M',
#   '212.188B',
#   '18.66',
#   ''],
#  ['LUMN',
#   'Lumen Technologies, Inc.',
#   '2.2500',
#   '0.0000',
#   '0.00%',
#   '36.963M',
#   '22.46M',
#   '2.26B',
#   'N/A',
#   ''],
#  ['DEI',
#   'Douglas Emmett, Inc.',
#   '12.76',
#   '-0.02',
#   '-0.16%',
#   '36.918M',
#   '3.649M',
#   '2.581B',
#   '25.02',
#   ''],
#  ['WFC',
#   'Wells Fargo & Company',
#   '42.18',
#   '-0.18',
#   '-0.42%',
#   '36.422M',
#   '23.563M',
#   '158.269B',
#   '12.19',
#   ''],
#  ['BTG',
#   'B2Gold Corp.',
#   '3.6600',
#   '+0.0900',
#   '+2.52%',
#   '36.376M',
#   '8.616M',
#   '4.738B',
#   '15.25',
#   ''],
#  ['VZ',
#   'Verizon Communications Inc.',
#   '36.46',
#   '+0.02',
#   '+0.05%',
#   '36.102M',
#   '19.534M',
#   '153.277B',
#   '7.09',
#   ''],
#  ['CVNA',
#   'Carvana Co.',
#   '25.32',
#   '-1.06',
#   '-4.02%',
#   '34.829M',
#   '22.907M',
#   '4.497B',
#   'N/A',
#   ''],
#  ['CMCSA',
#   'Comcast Corporation',
#   '41.20',
#   '-0.27',
#   '-0.65%',
#   '34.134M',
#   '18.901M',
#   '171.756B',
#   '30.75',
#   ''],
#  ['FULT',
#   'Fulton Financial Corporation',
#   '12.87',
#   '-0.23',
#   '-1.76%',
#   '33.877M',
#   '1.953M',
#   '2.13B',
#   '7.66',
#   ''],
#  ['U',
#   'Unity Software Inc.',
#   '42.56',
#   '+0.89',
#   '+2.14%',
#   '32.852M',
#   '10.716M',
#   '16.116B',
#   'N/A',
#   ''],
#  ['MU',
#   'Micron Technology, Inc.',
#   '67.66',
#   '-1.16',
#   '-1.69%',
#   '32.26M',
#   '18.93M',
#   '74.046B',
#   '48.68',
#   ''],
#  ['IMGN',
#   'ImmunoGen, Inc.',
#   '18.44',
#   '-0.26',
#   '-1.39%',
#   '32.053M',
#   '7.621M',
#   '4.72B',
#   'N/A',
#   ''],
#  ['KGC',
#   'Kinross Gold Corporation',
#   '4.8800',
#   '+0.0100',
#   '+0.21%',
#   '31.458M',
#   '13.537M',
#   '5.997B',
#   '162.67',
#   ''],
#  ['SWN',
#   'Southwestern Energy Company',
#   '5.55',
#   '+0.06',
#   '+1.09%',
#   '31.282M',
#   '20.697M',
#   '6.112B',
#   '0.94',
#   ''],
#  ['PLUG',
#   'Plug Power Inc.',
#   '10.57',
#   '-0.25',
#   '-2.31%',
#   '30.502M',
#   '24.004M',
#   '6.348B',
#   'N/A',
#   ''],
#  ['USB',
#   'U.S. Bancorp',
#   '33.45',
#   '+0.16',
#   '+0.48%',
#   '30.118M',
#   '18.413M',
#   '51.276B',
#   '8.94',
#   ''],
#  ['CSX',
#   'CSX Corporation',
#   '33.21',
#   '-0.35',
#   '-1.04%',
#   '30.05M',
#   '12.83M',
#   '67.518B',
#   '16.28',
#   ''],
#  ['NYCB',
#   'New York Community Bancorp, Inc.',
#   '10.65',
#   '-0.30',
#   '-2.74%',
#   '29.881M',
#   '16.499M',
#   '7.691B',
#   '2.79',
#   ''],
#  [],
#  ['PYPL',
#   'PayPal Holdings, Inc.',
#   '66.43',
#   '+0.58',
#   '+0.88%',
#   '29.704M',
#   '15.958M',
#   '74.117B',
#   '27.91',
#   ''],
#  ['SNAP',
#   'Snap Inc.',
#   '10.68',
#   '+0.02',
#   '+0.19%',
#   '28.86M',
#   '26.202M',
#   '17.107B',
#   'N/A',
#   ''],
#  ['KEY',
#   'KeyCorp',
#   '9.93',
#   '-0.15',
#   '-1.49%',
#   '28.307M',
#   '24.367M',
#   '9.287B',
#   '5.61',
#   ''],
#  ['ON',
#   'ON Semiconductor Corporation',
#   '90.15',
#   '-0.85',
#   '-0.93%',
#   '28.125M',
#   '6.992M',
#   '38.933B',
#   '22.15',
#   ''],
#  ['UBER',
#   'Uber Technologies, Inc.',
#   '43.52',
#   '+0.16',
#   '+0.37%',
#   '27.986M',
#   '23.237M',
#   '88.077B',
#   'N/A',
#   ''],
#  ['DAN',
#   'Dana Incorporated',
#   '16.81',
#   '+0.24',
#   '+1.45%',
#   '27.818M',
#   '1.514M',
#   '2.426B',
#   'N/A',
#   ''],
#  ['DNA',
#   'Ginkgo Bioworks Holdings, Inc.',
#   '1.9000',
#   '-0.0500',
#   '-2.56%',
#   '27.739M',
#   '20.512M',
#   '3.962B',
#   'N/A',
#   ''],
#  ['KO',
#   'The Coca-Cola Company',
#   '61.67',
#   '+0.44',
#   '+0.72%',
#   '26.738M',
#   '12.91M',
#   '266.697B',
#   '27.17',
#   ''],
#  ['HBAN',
#   'Huntington Bancshares Incorporated',
#   '10.92',
#   '+0.03',
#   '+0.28%',
#   '25.616M',
#   '17.418M',
#   '15.764B',
#   '7.05',
#   ''],
#  ['BABA',
#   'Alibaba Group Holding Limited',
#   '92.10',
#   '-0.10',
#   '-0.11%',
#   '25.088M',
#   '23.754M',
#   '240.039B',
#   '23.26',
#   ''],
#  ['HPE',
#   'Hewlett Packard Enterprise Company',
#   '17.57',
#   '+0.12',
#   '+0.69%',
#   '24.487M',
#   '13.177M',
#   '22.692B',
#   '21.96',
#   ''],
#  ['KMI',
#   'Kinder Morgan, Inc.',
#   '17.04',
#   '+0.03',
#   '+0.18%',
#   '24.028M',
#   '12.42M',
#   '38.306B',
#   '15.08',
#   ''],
#  ['PECO',
#   'Phillips Edison & Company, Inc.',
#   '34.09',
#   '+0.46',
#   '+1.37%',
#   '23.954M',
#   '1.052M',
#   '4.486B',
#   '72.53',
#   ''],
#  ['GRAB',
#   'Grab Holdings Limited',
#   '3.4200',
#   '-0.0200',
#   '-0.58%',
#   '23.694M',
#   '17.278M',
#   '13.294B',
#   'N/A',
#   ''],
#  ['VTRS',
#   'Viatris Inc.',
#   '10.29',
#   '+0.35',
#   '+3.52%',
#   '23.648M',
#   '9.607M',
#   '12.338B',
#   '6.35',
#   ''],
#  ['NEE',
#   'NextEra Energy, Inc.',
#   '75.59',
#   '+1.23',
#   '+1.65%',
#   '23.054M',
#   '7.053M',
#   '152.95B',
#   '22.43',
#   ''],
#  ['CVX',
#   'Chevron Corporation',
#   '157.26',
#   '-1.02',
#   '-0.64%',
#   '22.875M',
#   '7.567M',
#   '297.951B',
#   '8.49',
#   ''],
#  ['DIS',
#   'The Walt Disney Company',
#   '91.32',
#   '-1.62',
#   '-1.74%',
#   '22.683M',
#   '11.63M',
#   '166.869B',
#   '41.32',
#   ''],
#  ['AAL',
#   'American Airlines Group Inc.',
#   '16.48',
#   '-0.17',
#   '-1.02%',
#   '22.659M',
#   '24.523M',
#   '10.759B',
#   '6.10',
#   ''],
#  ['NU',
#   'Nu Holdings Ltd.',
#   '7.54',
#   '+0.13',
#   '+1.75%',
#   '22.103M',
#   '24.294M',
#   '35.399B',
#   'N/A',
#   ''],
#  ['BBD',
#   'Banco Bradesco S.A.',
#   '3.5100',
#   '-0.0100',
#   '-0.28%',
#   '21.858M',
#   '26.317M',
#   '37.297B',
#   '10.32',
#   ''],
#  ['CTRA',
#   'Coterra Energy Inc.',
#   '25.21',
#   '+0.13',
#   '+0.52%',
#   '21.776M',
#   '7.501M',
#   '19.095B',
#   '4.83',
#   ''],
#  ['TFC',
#   'Truist Financial Corporation',
#   '31.90',
#   '-0.32',
#   '-0.99%',
#   '21.751M',
#   '14.962M',
#   '42.488B',
#   '7.10',
#   ''],
#  ['PCG',
#   'PG&E Corporation',
#   '17.40',
#   '+0.15',
#   '+0.87%',
#   '21.681M',
#   '15.951M',
#   '43.039B',
#   '19.33',
#   ''],
#  ['BERY',
#   'Berry Global Group, Inc.',
#   '64.72',
#   '+1.36',
#   '+2.15%',
#   '21.599M',
#   '1.13M',
#   '7.715B',
#   '11.16',
#   ''],
#  [],
#  ['DOCS',
#   'Doximity, Inc.',
#   '32.54',
#   '+0.19',
#   '+0.59%',
#   '21.386M',
#   '1.871M',
#   '6.338B',
#   '61.40',
#   ''],
#  ['GLW',
#   'Corning Incorporated',
#   '35.85',
#   '+2.01',
#   '+5.94%',
#   '21.263M',
#   '4.814M',
#   '30.477B',
#   '33.82',
#   ''],
#  ['GOLD',
#   'Barrick Gold Corporation',
#   '16.71',
#   '+0.22',
#   '+1.33%',
#   '21.152M',
#   '15.296M',
#   '29.333B',
#   '278.50',
#   ''],
#  ['VALE',
#   'Vale S.A.',
#   '14.44',
#   '-0.03',
#   '-0.21%',
#   '20.758M',
#   '23.271M',
#   '63.112B',
#   '4.66',
#   ''],
#  ['CARG',
#   'CarGurus, Inc.',
#   '21.97',
#   '+0.19',
#   '+0.87%',
#   '20.624M',
#   '1.474M',
#   '2.49B',
#   '18.01',
#   ''],
#  ['ADT',
#   'ADT Inc.',
#   '6.42',
#   '+0.25',
#   '+4.05%',
#   '20.549M',
#   '3.429M',
#   '5.917B',
#   '214.00',
#   ''],
#  ['CCK',
#   'Crown Holdings, Inc.',
#   '88.81',
#   '+2.06',
#   '+2.37%',
#   '20.48M',
#   '1.279M',
#   '10.666B',
#   '17.41',
#   ''],
#  ['ABEV',
#   'Ambev S.A.',
#   '3.0900',
#   '-0.0400',
#   '-1.28%',
#   '20.357M',
#   '16.119M',
#   '48.66B',
#   '16.26',
#   ''],
#  ['NOK',
#   'Nokia Oyj',
#   '4.2800',
#   '+0.0400',
#   '+0.94%',
#   '20.156M',
#   '16.314M',
#   '23.998B',
#   '5.16',
#   ''],
#  ['NAVI',
#   'Navient Corporation',
#   '18.40',
#   '-0.38',
#   '-2.02%',
#   '20.077M',
#   '1.33M',
#   '2.327B',
#   '5.00',
#   ''],
#  ['WU',
#   'The Western Union Company',
#   '11.55',
#   '-0.08',
#   '-0.69%',
#   '19.769M',
#   '6.579M',
#   '4.325B',
#   '5.78',
#   ''],
#  ['SCHW',
#   'The Charles Schwab Corporation',
#   '54.40',
#   '-1.11',
#   '-2.00%',
#   '19.694M',
#   '21.422M',
#   '99.01B',
#   '14.86',
#   ''],
#  ['ORCL',
#   'Oracle Corporation',
#   '125.46',
#   '-1.09',
#   '-0.86%',
#   '19.515M',
#   '9.465M',
#   '338.717B',
#   '40.87',
#   ''],
#  ['AMCR',
#   'Amcor plc',
#   '10.35',
#   '+0.07',
#   '+0.68%',
#   '19.434M',
#   '7.804M',
#   '15.229B',
#   '15.92',
#   ''],
#  ['BMY',
#   'Bristol-Myers Squibb Company',
#   '66.16',
#   '+1.49',
#   '+2.30%',
#   '19.394M',
#   '7.851M',
#   '138.992B',
#   '19.29',
#   ''],
#  ['ENVX',
#   'Enovix Corporation',
#   '15.12',
#   '+1.49',
#   '+10.93%',
#   '19.342M',
#   '6.065M',
#   '2.391B',
#   'N/A',
#   ''],
#  ['APE',
#   'AMC Entertainment Holdings, Inc.',
#   '1.7400',
#   '+0.0500',
#   '+2.96%',
#   '19.174M',
#   '13.07M',
#   '4.538B',
#   'N/A',
#   ''],
#  ['AMC',
#   'AMC Entertainment Holdings, Inc.',
#   '4.7000',
#   '-0.0600',
#   '-1.26%',
#   '18.764M',
#   '22.456M',
#   '3.947B',
#   'N/A',
#   ''],
#  ['O',
#   'Realty Income Corporation',
#   '61.39',
#   '+0.16',
#   '+0.26%',
#   '18.48M',
#   '3.836M',
#   '41.329B',
#   '43.23',
#   ''],
#  ['MRO',
#   'Marathon Oil Corporation',
#   '23.50',
#   '+0.21',
#   '+0.90%',
#   '18.402M',
#   '11.208M',
#   '14.514B',
#   '5.68',
#   ''],
#  ['ITUB',
#   'Itaú Unibanco Holding S.A.',
#   '5.90',
#   '0.00',
#   '0.00%',
#   '18.297M',
#   '24.295M',
#   '57.82B',
#   '9.22',
#   ''],
#  ['INFY',
#   'Infosys Limited',
#   '15.83',
#   '+0.21',
#   '+1.34%',
#   '18.246M',
#   '11.387M',
#   '65.505B',
#   '22.30',
#   ''],
#  ['C',
#   'Citigroup Inc.',
#   '48.19',
#   '-0.37',
#   '-0.76%',
#   '18.223M',
#   '16.457M',
#   '93.814B',
#   '6.62',
#   ''],
#  ['CVS',
#   'CVS Health Corporation',
#   '67.72',
#   '-1.78',
#   '-2.56%',
#   '18.211M',
#   '8.566M',
#   '86.819B',
#   '22.50',
#   ''],
#  ['M',
#   "Macy's, Inc.",
#   '15.85',
#   '-0.14',
#   '-0.88%',
#   '17.844M',
#   '12.825M',
#   '4.32B',
#   '4.20',
#   ''],
#  [],
#  ['HL',
#   'Hecla Mining Company',
#   '5.29',
#   '+0.06',
#   '+1.15%',
#   '17.706M',
#   '7.272M',
#   '3.241B',
#   'N/A',
#   ''],
#  ['CRC',
#   'California Resources Corporation',
#   '44.32',
#   '+1.52',
#   '+3.55%',
#   '17.635M',
#   '996,217',
#   '3.151B',
#   '3.23',
#   ''],
#  ['RF',
#   'Regions Financial Corporation',
#   '18.12',
#   '-0.20',
#   '-1.09%',
#   '17.529M',
#   '11.358M',
#   '17.002B',
#   '7.71',
#   ''],
#  ['XPEV',
#   'XPeng Inc.',
#   '11.38',
#   '-0.21',
#   '-1.81%',
#   '17.491M',
#   '13.328M',
#   '9.954B',
#   'N/A',
#   ''],
#  ['MRVL',
#   'Marvell Technology, Inc.',
#   '61.12',
#   '-0.91',
#   '-1.47%',
#   '17.329M',
#   '14.657M',
#   '52.563B',
#   'N/A',
#   ''],
#  ['NEM',
#   'Newmont Corporation',
#   '43.83',
#   '+1.13',
#   '+2.65%',
#   '17.163M',
#   '8.314M',
#   '34.833B',
#   'N/A',
#   ''],
#  ['LU',
#   'Lufax Holding Ltd',
#   '1.5600',
#   '-0.1200',
#   '-7.14%',
#   '16.932M',
#   '9.801M',
#   '7.911B',
#   '6.24',
#   ''],
#  ['ENLC',
#   'EnLink Midstream, LLC',
#   '10.31',
#   '0.00',
#   '0.00%',
#   '16.509M',
#   '2.491M',
#   '4.804B',
#   '13.05',
#   ''],
#  ['S',
#   'SentinelOne, Inc.',
#   '16.09',
#   '-0.56',
#   '-3.36%',
#   '16.472M',
#   '8.349M',
#   '4.686B',
#   'N/A',
#   ''],
#  ['DVN',
#   'Devon Energy Corporation',
#   '49.80',
#   '+0.20',
#   '+0.40%',
#   '16.259M',
#   '8.209M',
#   '31.957B',
#   '5.43',
#   ''],
#  ['FCX',
#   'Freeport-McMoRan Inc.',
#   '39.89',
#   '-0.19',
#   '-0.47%',
#   '16.144M',
#   '12.537M',
#   '57.174B',
#   '22.16',
#   ''],
#  ['WBA',
#   'Walgreens Boots Alliance, Inc.',
#   '32.67',
#   '+0.65',
#   '+2.03%',
#   '16.021M',
#   '7.109M',
#   '28.188B',
#   'N/A',
#   ''],
#  ['MRK',
#   'Merck & Co., Inc.',
#   '109.32',
#   '-0.08',
#   '-0.07%',
#   '15.844M',
#   '6.924M',
#   '277.393B',
#   '21.35',
#   ''],
#  ['NWL',
#   'Newell Brands Inc.',
#   '8.51',
#   '-0.03',
#   '-0.35%',
#   '15.812M',
#   '6.426M',
#   '3.524B',
#   'N/A',
#   ''],
#  ['NCLH',
#   'Norwegian Cruise Line Holdings Ltd.',
#   '19.13',
#   '-0.41',
#   '-2.10%',
#   '15.741M',
#   '14.385M',
#   '8.114B',
#   'N/A',
#   ''],
#  ['PBR-A',
#   'Petróleo Brasileiro S.A. - Petrobras',
#   '12.37',
#   '+0.06',
#   '+0.49%',
#   '15.66M',
#   '9.244M',
#   '85.44B',
#   '2.28',
#   ''],
#  ['FHN',
#   'First Horizon Corporation',
#   '11.75',
#   '-0.04',
#   '-0.34%',
#   '15.644M',
#   '12.732M',
#   '6.319B',
#   '7.25',
#   ''],
#  ['KDP',
#   'Keurig Dr Pepper Inc.',
#   '32.17',
#   '+0.41',
#   '+1.29%',
#   '15.547M',
#   '9.237M',
#   '45.16B',
#   '34.59',
#   ''],
#  ['RLX',
#   'RLX Technology Inc.',
#   '1.9400',
#   '-0.0200',
#   '-1.02%',
#   '15.498M',
#   '9.014M',
#   '3.047B',
#   '24.25',
#   ''],
#  ['RBLX',
#   'Roblox Corporation',
#   '41.80',
#   '+1.17',
#   '+2.88%',
#   '15.38M',
#   '9.297M',
#   '25.526B',
#   'N/A',
#   ''],
#  ['TEVA',
#   'Teva Pharmaceutical Industries Limited',
#   '7.54',
#   '-0.04',
#   '-0.53%',
#   '15.293M',
#   '13.351M',
#   '8.531B',
#   'N/A',
#   ''],
#  ['WY',
#   'Weyerhaeuser Company',
#   '31.00',
#   '+0.24',
#   '+0.78%',
#   '15.284M',
#   '4.073M',
#   '22.701B',
#   '18.13',
#   ''],
#  ['PBR',
#   'Petróleo Brasileiro S.A. - Petrobras',
#   '13.90',
#   '+0.11',
#   '+0.80%',
#   '15.221M',
#   '20.959M',
#   '90.657B',
#   '2.56',
#   ''],
#  ['BWXT',
#   'BWX Technologies, Inc.',
#   '69.73',
#   '+2.00',
#   '+2.95%',
#   '15.143M',
#   '752,269',
#   '6.377B',
#   '26.51',
#   ''],
#  ['MC',
#   'Moelis & Company',
#   '45.38',
#   '-1.15',
#   '-2.47%',
#   '15.14M',
#   '872,746',
#   '3.021B',
#   '37.20',
#   ''],
#  [],
#  ['PTEN',
#   'Patterson-UTI Energy, Inc.',
#   '11.71',
#   '-0.77',
#   '-6.17%',
#   '14.792M',
#   '3.65M',
#   '2.436B',
#   '9.08',
#   ''],
#  ['SLB',
#   'Schlumberger Limited',
#   '47.78',
#   '-0.12',
#   '-0.25%',
#   '14.741M',
#   '9.78M',
#   '68.102B',
#   '17.83',
#   ''],
#  ['ABBV',
#   'AbbVie Inc.',
#   '138.64',
#   '+2.75',
#   '+2.02%',
#   '14.616M',
#   '5.402M',
#   '244.601B',
#   '31.94',
#   ''],
#  ['GM',
#   'General Motors Company',
#   '37.96',
#   '-0.07',
#   '-0.18%',
#   '14.523M',
#   '14.154M',
#   '52.769B',
#   '5.88',
#   ''],
#  ['NKE',
#   'NIKE, Inc.',
#   '113.59',
#   '+1.18',
#   '+1.05%',
#   '14.446M',
#   '7.2M',
#   '174.587B',
#   '32.83',
#   ''],
#  ['PATH',
#   'UiPath Inc.',
#   '18.10',
#   '-0.65',
#   '-3.47%',
#   '14.386M',
#   '9.245M',
#   '10.157B',
#   'N/A',
#   ''],
#  ['LYFT',
#   'Lyft, Inc.',
#   '10.26',
#   '-0.29',
#   '-2.75%',
#   '14.379M',
#   '18.613M',
#   '3.88B',
#   'N/A',
#   ''],
#  ['APAM',
#   'Artisan Partners Asset Management Inc.',
#   '38.93',
#   '-0.25',
#   '-0.64%',
#   '14.238M',
#   '757,269',
#   '2.665B',
#   '14.11',
#   ''],
#  ['PLNT',
#   'Planet Fitness, Inc.',
#   '70.66',
#   '+0.70',
#   '+1.00%',
#   '14.185M',
#   '1.312M',
#   '6.302B',
#   '56.98',
#   ''],
#  ['HOOD',
#   'Robinhood Markets, Inc.',
#   '10.03',
#   '+0.05',
#   '+0.50%',
#   '14.175M',
#   '7.156M',
#   '9.057B',
#   'N/A',
#   ''],
#  ['WMB',
#   'The Williams Companies, Inc.',
#   '30.53',
#   '-0.04',
#   '-0.13%',
#   '14.135M',
#   '6.779M',
#   '37.191B',
#   '14.40',
#   ''],
#  ['DKNG',
#   'DraftKings Inc.',
#   '24.51',
#   '-0.32',
#   '-1.29%',
#   '14.108M',
#   '11.699M',
#   '11.32B',
#   'N/A',
#   ''],
#  ['GILD',
#   'Gilead Sciences, Inc.',
#   '78.86',
#   '-0.14',
#   '-0.18%',
#   '13.983M',
#   '5.462M',
#   '98.366B',
#   '17.84',
#   ''],
#  ['ACI',
#   'Albertsons Companies, Inc.',
#   '21.37',
#   '+0.13',
#   '+0.61%',
#   '13.976M',
#   '4.524M',
#   '12.265B',
#   '9.41',
#   ''],
#  ['RIG',
#   'Transocean Ltd.',
#   '6.23',
#   '+0.01',
#   '+0.16%',
#   '13.966M',
#   '15.967M',
#   '4.775B',
#   'N/A',
#   ''],
#  ['HPQ',
#   'HP Inc.',
#   '31.00',
#   '-0.10',
#   '-0.32%',
#   '13.963M',
#   '7.032M',
#   '30.565B',
#   '11.61',
#   ''],
#  ['JPM',
#   'JPMorgan Chase & Co.',
#   '143.26',
#   '+0.17',
#   '+0.12%',
#   '13.814M',
#   '12.048M',
#   '418.647B',
#   '10.56',
#   ''],
#  ['COIN',
#   'Coinbase Global, Inc.',
#   '55.59',
#   '+1.34',
#   '+2.47%',
#   '13.754M',
#   '15.307M',
#   '13.039B',
#   'N/A',
#   ''],
#  ['OXY',
#   'Occidental Petroleum Corporation',
#   '58.15',
#   '-0.27',
#   '-0.46%',
#   '13.741M',
#   '11.452M',
#   '51.855B',
#   '6.65',
#   ''],
#  ['CRM',
#   'Salesforce, Inc.',
#   '211.76',
#   '-0.16',
#   '-0.08%',
#   '13.673M',
#   '6.549M',
#   '206.254B',
#   '557.26',
#   ''],
#  ['MO',
#   'Altria Group, Inc.',
#   '44.07',
#   '-0.08',
#   '-0.18%',
#   '13.663M',
#   '7.827M',
#   '78.667B',
#   '14.17',
#   ''],
#  ['V',
#   'Visa Inc.',
#   '228.91',
#   '+2.74',
#   '+1.21%',
#   '13.629M',
#   '6.56M',
#   '479.429B',
#   '30.56',
#   ''],
#  ['GNW',
#   'Genworth Financial, Inc.',
#   '5.07',
#   '-0.23',
#   '-4.34%',
#   '13.58M',
#   '3.771M',
#   '2.423B',
#   '5.63',
#   ''],
#  ['SHOP',
#   'Shopify Inc.',
#   '64.71',
#   '-1.39',
#   '-2.10%',
#   '13.568M',
#   '15.9M',
#   '82.761B',
#   'N/A',
#   ''],
#  ['JNJ',
#   'Johnson & Johnson',
#   '164.23',
#   '+0.50',
#   '+0.31%',
#   '13.427M',
#   '6.908M',
#   '426.789B',
#   '34.50',
#   ''],
#  [],
#  ['ADBE',
#   'Adobe Inc.',
#   '495.18',
#   '+4.27',
#   '+0.87%',
#   '13.344M',
#   '3.684M',
#   '227.139B',
#   '47.57',
#   ''],
#  ['CHPT',
#   'ChargePoint Holdings, Inc.',
#   '8.88',
#   '-0.17',
#   '-1.88%',
#   '13.322M',
#   '9.656M',
#   '3.137B',
#   'N/A',
#   ''],
#  ['SDGR',
#   'Schrödinger, Inc.',
#   '45.98',
#   '+0.72',
#   '+1.59%',
#   '13.271M',
#   '1.089M',
#   '3.289B',
#   '353.69',
#   ''],
#  ['MPW',
#   'Medical Properties Trust, Inc.',
#   '9.18',
#   '+0.06',
#   '+0.66%',
#   '13.231M',
#   '14.236M',
#   '5.492B',
#   '18.36',
#   ''],
#  ['BZ',
#   'Kanzhun Limited',
#   '17.23',
#   '+0.18',
#   '+1.06%',
#   '13.225M',
#   '3.125M',
#   '7.486B',
#   '344.60',
#   ''],
#  ['MS',
#   'Morgan Stanley',
#   '88.09',
#   '-0.96',
#   '-1.08%',
#   '13.153M',
#   '6.985M',
#   '147.12B',
#   '15.11',
#   ''],
#  ['BSX',
#   'Boston Scientific Corporation',
#   '54.32',
#   '+0.34',
#   '+0.63%',
#   '13.023M',
#   '9.292M',
#   '78.096B',
#   '90.53',
#   ''],
#  ['PARA',
#   'Paramount Global',
#   '16.28',
#   '-0.25',
#   '-1.51%',
#   '13.016M',
#   '14.788M',
#   '10.707B',
#   'N/A',
#   ''],
#  ['TMUS',
#   'T-Mobile US, Inc.',
#   '130.93',
#   '-1.83',
#   '-1.38%',
#   '13.015M',
#   '6.57M',
#   '157.102B',
#   '43.35',
#   ''],
#  ['PINS',
#   'Pinterest, Inc.',
#   '25.36',
#   '+0.40',
#   '+1.60%',
#   '12.968M',
#   '11.304M',
#   '17.34B',
#   'N/A',
#   ''],
#  ['IQ',
#   'iQIYI, Inc.',
#   '5.50',
#   '0.00',
#   '0.00%',
#   '12.927M',
#   '11.243M',
#   '5.262B',
#   '137.50',
#   ''],
#  ['QCOM',
#   'QUALCOMM Incorporated',
#   '122.68',
#   '-0.93',
#   '-0.75%',
#   '12.906M',
#   '7.963M',
#   '136.666B',
#   '13.08',
#   ''],
#  ['NEX',
#   'NexTier Oilfield Solutions Inc.',
#   '8.84',
#   '-0.68',
#   '-7.14%',
#   '12.808M',
#   '3.56M',
#   '2.038B',
#   '3.32',
#   ''],
#  ['BK',
#   'The Bank of New York Mellon Corporation',
#   '44.65',
#   '-0.22',
#   '-0.49%',
#   '12.632M',
#   '5.27M',
#   '35.235B',
#   '14.22',
#   ''],
#  ['RBA',
#   'RB Global, Inc.',
#   '57.09',
#   '+0.04',
#   '+0.07%',
#   '12.524M',
#   '2.229M',
#   '10.378B',
#   '58.26',
#   ''],
#  ['PDD',
#   'PDD Holdings Inc.',
#   '79.87',
#   '-0.95',
#   '-1.18%',
#   '12.517M',
#   '10.036M',
#   '106.114B',
#   '21.94',
#   ''],
#  ['BKR',
#   'Baker Hughes Company',
#   '30.57',
#   '+0.33',
#   '+1.09%',
#   '12.507M',
#   '7.103M',
#   '31.162B',
#   'N/A',
#   ''],
#  ['TME',
#   'Tencent Music Entertainment Group',
#   '8.03',
#   '-0.30',
#   '-3.60%',
#   '12.477M',
#   '6.779M',
#   '14.434B',
#   '22.94',
#   ''],
#  ['AR',
#   'Antero Resources Corporation',
#   '22.46',
#   '+0.70',
#   '+3.22%',
#   '12.428M',
#   '5.461M',
#   '6.741B',
#   '3.12',
#   ''],
#  ['CRK',
#   'Comstock Resources, Inc.',
#   '10.47',
#   '-0.21',
#   '-1.97%',
#   '12.418M',
#   '3.722M',
#   '2.906B',
#   '2.05',
#   ''],
#  ['AFRM',
#   'Affirm Holdings, Inc.',
#   '16.67',
#   '-0.61',
#   '-3.53%',
#   '12.288M',
#   '16.224M',
#   '4.929B',
#   'N/A',
#   ''],
#  ['AES',
#   'The AES Corporation',
#   '21.34',
#   '-0.15',
#   '-0.70%',
#   '12.279M',
#   '5.8M',
#   '14.284B',
#   'N/A',
#   ''],
#  ['MOS',
#   'The Mosaic Company',
#   '35.82',
#   '+0.54',
#   '+1.53%',
#   '12.261M',
#   '4.389M',
#   '11.896B',
#   '4.40',
#   ''],
#  ['SQ',
#   'Block, Inc.',
#   '66.51',
#   '+0.32',
#   '+0.48%',
#   '12.251M',
#   '14.672M',
#   '40.232B',
#   'N/A',
#   ''],
#  ['KHC',
#   'The Kraft Heinz Company',
#   '36.99',
#   '+0.12',
#   '+0.33%',
#   '12.251M',
#   '6.772M',
#   '45.396B',
#   '18.87',
#   ''],
#  [],
#  ['ATVI',
#   'Activision Blizzard, Inc.',
#   '81.97',
#   '+0.52',
#   '+0.64%',
#   '12.237M',
#   '7.672M',
#   '64.441B',
#   '34.59',
#   ''],
#  ['DAL',
#   'Delta Air Lines, Inc.',
#   '42.79',
#   '-0.09',
#   '-0.21%',
#   '12.219M',
#   '10.568M',
#   '27.502B',
#   '14.41',
#   ''],
#  ['CVT',
#   'Cvent Holding Corp.',
#   '8.52',
#   '0.00',
#   '0.00%',
#   '12.223M',
#   '2.29M',
#   '4.189B',
#   'N/A',
#   ''],
#  ['CFG',
#   'Citizens Financial Group, Inc.',
#   '27.26',
#   '-0.43',
#   '-1.55%',
#   '11.761M',
#   '9.185M',
#   '13.194B',
#   '6.54',
#   ''],
#  ['SBUX',
#   'Starbucks Corporation',
#   '101.87',
#   '+0.49',
#   '+0.48%',
#   '11.709M',
#   '6.25M',
#   '116.784B',
#   '33.07',
#   ''],
#  ['WELL',
#   'Welltower Inc.',
#   '80.41',
#   '+0.26',
#   '+0.32%',
#   '11.643M',
#   '2.414M',
#   '39.966B',
#   '309.27',
#   ''],
#  ['AGI',
#   'Alamos Gold Inc.',
#   '12.24',
#   '+0.10',
#   '+0.82%',
#   '11.586M',
#   '3.13M',
#   '4.833B',
#   '53.22',
#   ''],
#  ['BALL',
#   'Ball Corporation',
#   '58.43',
#   '+3.94',
#   '+7.23%',
#   '11.573M',
#   '1.841M',
#   '18.379B',
#   '37.94',
#   ''],
#  ['EQT',
#   'EQT Corporation',
#   '39.64',
#   '+0.69',
#   '+1.77%',
#   '11.57M',
#   '6.436M',
#   '14.336B',
#   '3.38',
#   ''],
#  ['WMT',
#   'Walmart Inc.',
#   '155.53',
#   '-2.20',
#   '-1.39%',
#   '11.559M',
#   '6.205M',
#   '418.817B',
#   '37.48',
#   ''],
#  ['TSM',
#   'Taiwan Semiconductor Manufacturing Company Limited',
#   '104.57',
#   '-0.61',
#   '-0.58%',
#   '11.431M',
#   '11.932M',
#   '542.343B',
#   '16.73',
#   ''],
#  ['NRG',
#   'NRG Energy, Inc.',
#   '34.12',
#   '-0.25',
#   '-0.73%',
#   '11.339M',
#   '4.595M',
#   '7.856B',
#   'N/A',
#   ''],
#  ['JBLU',
#   'JetBlue Airways Corporation',
#   '8.06',
#   '+0.06',
#   '+0.75%',
#   '11.273M',
#   '8.941M',
#   '2.643B',
#   'N/A',
#   ''],
#  ['PG',
#   'The Procter & Gamble Company',
#   '149.54',
#   '+1.09',
#   '+0.73%',
#   '11.245M',
#   '6.003M',
#   '352.461B',
#   '25.96',
#   ''],
#  ['PTON',
#   'Peloton Interactive, Inc.',
#   '8.64',
#   '-0.32',
#   '-3.57%',
#   '11.196M',
#   '10.224M',
#   '3.061B',
#   'N/A',
#   ''],
#  ['FITB',
#   'Fifth Third Bancorp',
#   '26.54',
#   '-0.22',
#   '-0.82%',
#   '11.162M',
#   '8.056M',
#   '18.066B',
#   '7.69',
#   ''],
#  ['JD',
#   'JD.com, Inc.',
#   '39.85',
#   '-0.11',
#   '-0.28%',
#   '11.065M',
#   '11.735M',
#   '63.335B',
#   '23.30',
#   ''],
#  ['GE',
#   'General Electric Company',
#   '106.29',
#   '+0.88',
#   '+0.83%',
#   '10.959M',
#   '5.902M',
#   '115.886B',
#   '14.66',
#   ''],
#  ['FTNT',
#   'Fortinet, Inc.',
#   '72.78',
#   '-0.81',
#   '-1.10%',
#   '10.916M',
#   '4.787M',
#   '57.147B',
#   '61.16',
#   ''],
#  ['MDLZ',
#   'Mondelez International, Inc.',
#   '73.57',
#   '+0.11',
#   '+0.15%',
#   '10.885M',
#   '5.987M',
#   '100.191B',
#   '25.63',
#   ''],
#  ['HD',
#   'The Home Depot, Inc.',
#   '300.38',
#   '-1.64',
#   '-0.54%',
#   '10.809M',
#   '4.387M',
#   '301.996B',
#   '18.28',
#   ''],
#  ['MPC',
#   'Marathon Petroleum Corporation',
#   '113.29',
#   '-0.54',
#   '-0.47%',
#   '10.771M',
#   '4.084M',
#   '48.715B',
#   '3.48',
#   ''],
#  ['JOBY',
#   'Joby Aviation, Inc.',
#   '7.40',
#   '-0.53',
#   '-6.68%',
#   '10.768M',
#   '4.1M',
#   '4.993B',
#   'N/A',
#   ''],
#  ['TOST',
#   'Toast, Inc.',
#   '21.71',
#   '-1.32',
#   '-5.73%',
#   '10.599M',
#   '6.205M',
#   '11.517B',
#   'N/A',
#   ''],
#  ['KR',
#   'The Kroger Co.',
#   '46.17',
#   '+0.23',
#   '+0.50%',
#   '10.578M',
#   '5.608M',
#   '33.134B',
#   '13.27',
#   ''],
#  [],
#  ['ELAN',
#   'Elanco Animal Health Incorporated',
#   '10.37',
#   '+0.16',
#   '+1.57%',
#   '10.444M',
#   '7.901M',
#   '5.108B',
#   'N/A',
#   ''],
#  ['LAZR',
#   'Luminar Technologies, Inc.',
#   '6.87',
#   '-0.20',
#   '-2.83%',
#   '10.422M',
#   '8.396M',
#   '2.619B',
#   'N/A',
#   ''],
#  ['HAL',
#   'Halliburton Company',
#   '32.58',
#   '-0.13',
#   '-0.40%',
#   '10.394M',
#   '9.849M',
#   '29.394B',
#   '15.08',
#   ''],
#  ['HMY',
#   'Harmony Gold Mining Company Limited',
#   '4.5100',
#   '-0.0500',
#   '-1.10%',
#   '10.391M',
#   '4.33M',
#   '2.873B',
#   'N/A',
#   ''],
#  ['TXN',
#   'Texas Instruments Incorporated',
#   '176.76',
#   '-1.33',
#   '-0.75%',
#   '10.375M',
#   '4.938M',
#   '160.437B',
#   '19.82',
#   ''],
#  ['AIG',
#   'American International Group, Inc.',
#   '57.30',
#   '+0.68',
#   '+1.20%',
#   '10.319M',
#   '4.487M',
#   '41.471B',
#   '7.16',
#   ''],
#  ['MET',
#   'MetLife, Inc.',
#   '55.50',
#   '+0.34',
#   '+0.62%',
#   '10.278M',
#   '5.916M',
#   '42.503B',
#   '53.37',
#   ''],
#  ['Z',
#   'Zillow Group, Inc.',
#   '46.68',
#   '-1.48',
#   '-3.07%',
#   '10.277M',
#   '2.505M',
#   '10.866B',
#   'N/A',
#   ''],
#  ['FOXA',
#   'Fox Corporation',
#   '33.64',
#   '-0.03',
#   '-0.09%',
#   '10.266M',
#   '3.898M',
#   '16.47B',
#   '15.72',
#   ''],
#  ['RKLB',
#   'Rocket Lab USA, Inc.',
#   '5.60',
#   '-0.08',
#   '-1.41%',
#   '10.221M',
#   '3.509M',
#   '2.681B',
#   'N/A',
#   ''],
#  ['CLF',
#   'Cleveland-Cliffs Inc.',
#   '16.47',
#   '-0.31',
#   '-1.85%',
#   '10.194M',
#   '9.645M',
#   '8.483B',
#   '18.30',
#   ''],
#  ['GEN',
#   'Gen Digital Inc.',
#   '18.63',
#   '-0.22',
#   '-1.17%',
#   '10.175M',
#   '4.58M',
#   '11.938B',
#   '8.62',
#   ''],
#  ['NLY',
#   'Annaly Capital Management, Inc.',
#   '20.59',
#   '-0.30',
#   '-1.44%',
#   '10.158M',
#   '4.545M',
#   '10.169B',
#   'N/A',
#   ''],
#  ['CTVA',
#   'Corteva, Inc.',
#   '57.23',
#   '-0.45',
#   '-0.78%',
#   '10.092M',
#   '2.906M',
#   '40.683B',
#   '33.86',
#   ''],
#  ['ABT',
#   'Abbott Laboratories',
#   '106.20',
#   '+1.18',
#   '+1.12%',
#   '10.021M',
#   '5.066M',
#   '184.676B',
#   '32.28',
#   ''],
#  ['UMC',
#   'United Microelectronics Corporation',
#   '8.75',
#   '-0.17',
#   '-1.91%',
#   '9.946M',
#   '6.576M',
#   '22.208B',
#   '7.88',
#   ''],
#  ['VLO',
#   'Valero Energy Corporation',
#   '114.21',
#   '+0.18',
#   '+0.16%',
#   '9.939M',
#   '4.594M',
#   '41.289B',
#   '3.25',
#   ''],
#  ['COP',
#   'ConocoPhillips',
#   '104.92',
#   '+0.77',
#   '+0.74%',
#   '9.928M',
#   '6.116M',
#   '126.959B',
#   '8.35',
#   ''],
#  ['TGT',
#   'Target Corporation',
#   '133.81',
#   '-4.03',
#   '-2.92%',
#   '9.903M',
#   '4.802M',
#   '61.761B',
#   '22.80',
#   ''],
#  ['TAL',
#   'TAL Education Group',
#   '6.52',
#   '-0.02',
#   '-0.31%',
#   '9.869M',
#   '7.374M',
#   '4.163B',
#   'N/A',
#   ''],
#  ['D',
#   'Dominion Energy, Inc.',
#   '53.33',
#   '+0.46',
#   '+0.87%',
#   '9.868M',
#   '3.86M',
#   '44.581B',
#   '37.03',
#   ''],
#  ['CIG',
#   'Companhia Energética de Minas Gerais',
#   '2.5300',
#   '-0.1000',
#   '-3.80%',
#   '9.825M',
#   '4.11M',
#   '6.712B',
#   '6.66',
#   ''],
#  ['ERIC',
#   'Telefonaktiebolaget LM Ericsson (publ)',
#   '5.43',
#   '+0.01',
#   '+0.18%',
#   '9.771M',
#   '9.135M',
#   '18.083B',
#   '11.31',
#   ''],
#  ['PR',
#   'Permian Resources Corporation',
#   '10.50',
#   '+0.06',
#   '+0.57%',
#   '9.657M',
#   '6.199M',
#   '5.879B',
#   '5.59',
#   ''],
#  ['EXC',
#   'Exelon Corporation',
#   '41.21',
#   '+0.39',
#   '+0.96%',
#   '9.595M',
#   '6.766M',
#   '40.986B',
#   '18.23',
#   ''],
#  [],
#  ['CARR',
#   'Carrier Global Corporation',
#   '46.88',
#   '+0.34',
#   '+0.73%',
#   '9.588M',
#   '5.784M',
#   '39.137B',
#   '15.84',
#   ''],
#  ['PM',
#   'Philip Morris International Inc.',
#   '94.89',
#   '+0.16',
#   '+0.17%',
#   '9.547M',
#   '4.306M',
#   '147.288B',
#   '16.97',
#   ''],
#  ['DOW',
#   'Dow Inc.',
#   '53.16',
#   '-0.32',
#   '-0.60%',
#   '9.536M',
#   '4.603M',
#   '37.601B',
#   '13.26',
#   ''],
#  ['RUN',
#   'Sunrun Inc.',
#   '19.34',
#   '-0.74',
#   '-3.69%',
#   '9.381M',
#   '9.6M',
#   '4.17B',
#   '193.40',
#   ''],
#  ['CPNG',
#   'Coupang, Inc.',
#   '17.28',
#   '+0.31',
#   '+1.83%',
#   '9.379M',
#   '7.313M',
#   '30.739B',
#   '144.00',
#   ''],
#  ['DELL',
#   'Dell Technologies Inc.',
#   '49.67',
#   '-0.53',
#   '-1.06%',
#   '9.363M',
#   '4.481M',
#   '36.122B',
#   '18.67',
#   ''],
#  ['SO',
#   'The Southern Company',
#   '71.76',
#   '+1.00',
#   '+1.41%',
#   '9.35M',
#   '4.268M',
#   '78.247B',
#   '23.30',
#   ''],
#  ['VFC',
#   'V.F. Corporation',
#   '19.51',
#   '+0.16',
#   '+0.83%',
#   '9.335M',
#   '6.76M',
#   '7.584B',
#   '62.94',
#   ''],
#  ['ET',
#   'Energy Transfer LP',
#   '12.82',
#   '-0.02',
#   '-0.16%',
#   '9.324M',
#   '9.53M',
#   '40.271B',
#   '9.57',
#   ''],
#  ['AQN',
#   'Algonquin Power & Utilities Corp.',
#   '8.41',
#   '+0.09',
#   '+1.08%',
#   '9.216M',
#   '5.265M',
#   '5.792B',
#   'N/A',
#   ''],
#  ['MCHP',
#   'Microchip Technology Incorporated',
#   '85.49',
#   '+0.12',
#   '+0.14%',
#   '9.205M',
#   '4.935M',
#   '46.625B',
#   '21.27',
#   ''],
#  ['DCP',
#   'DCP Midstream, LP',
#   '41.69',
#   '+0.03',
#   '+0.07%',
#   '9.522M',
#   '1.069M',
#   '8.699B',
#   '7.75',
#   ''],
#  ['VLY',
#   'Valley National Bancorp',
#   '8.32',
#   '-0.11',
#   '-1.30%',
#   '9.13M',
#   '6.743M',
#   '4.226B',
#   '7.23',
#   ''],
#  ['MDT',
#   'Medtronic plc',
#   '89.15',
#   '+0.90',
#   '+1.02%',
#   '9.109M',
#   '6.047M',
#   '118.642B',
#   '31.61',
#   ''],
#  ['APA',
#   'APA Corporation',
#   '34.38',
#   '-0.29',
#   '-0.84%',
#   '9.093M',
#   '5.957M',
#   '10.61B',
#   '5.40',
#   ''],
#  ['HST',
#   'Host Hotels & Resorts, Inc.',
#   '17.05',
#   '-0.06',
#   '-0.35%',
#   '9.093M',
#   '6.625M',
#   '12.127B',
#   '15.22',
#   ''],
#  ['RTX',
#   'Raytheon Technologies Corporation',
#   '97.74',
#   '-0.26',
#   '-0.27%',
#   '9.038M',
#   '4.171M',
#   '142.812B',
#   '26.13',
#   ''],
#  ['ARCC',
#   'Ares Capital Corporation',
#   '18.68',
#   '+0.03',
#   '+0.16%',
#   '8.978M',
#   '3.102M',
#   '10.173B',
#   '14.71',
#   ''],
#  ['PEP',
#   'PepsiCo, Inc.',
#   '186.04',
#   '+0.33',
#   '+0.18%',
#   '8.926M',
#   '4.275M',
#   '256.305B',
#   '39.08',
#   ''],
#  ['AGNC',
#   'AGNC Investment Corp.',
#   '10.21',
#   '-0.04',
#   '-0.39%',
#   '8.898M',
#   '10.53M',
#   '6.082B',
#   'N/A',
#   ''],
#  ['AMAT',
#   'Applied Materials, Inc.',
#   '138.93',
#   '-1.18',
#   '-0.84%',
#   '8.847M',
#   '5.99M',
#   '116.666B',
#   '18.30',
#   ''],
#  ['BCS',
#   'Barclays PLC',
#   '7.93',
#   '+0.01',
#   '+0.13%',
#   '8.805M',
#   '9.392M',
#   '30.834B',
#   '4.81',
#   ''],
#  ['IOT',
#   'Samsara Inc.',
#   '28.90',
#   '-0.15',
#   '-0.52%',
#   '8.781M',
#   '3.76M',
#   '15.275B',
#   'N/A',
#   ''],
#  ['NFLX',
#   'Netflix, Inc.',
#   '431.96',
#   '-13.31',
#   '-2.99%',
#   '8.754M',
#   '7.074M',
#   '192.024B',
#   '47.42',
#   ''],
#  ['LUV',
#   'Southwest Airlines Co.',
#   '34.25',
#   '+0.28',
#   '+0.82%',
#   '8.743M',
#   '6.878M',
#   '20.381B',
#   '32.01',
#   ''],
#  [],
#  ['GPS',
#   'The Gap, Inc.',
#   '9.58',
#   '-0.13',
#   '-1.34%',
#   '8.731M',
#   '9.483M',
#   '3.526B',
#   'N/A',
#   ''],
#  ['DUK',
#   'Duke Energy Corporation',
#   '92.18',
#   '+0.49',
#   '+0.53%',
#   '8.694M',
#   '3.03M',
#   '71.039B',
#   '18.89',
#   ''],
#  ['CD',
#   'Chindata Group Holdings Limited',
#   '7.29',
#   '-0.08',
#   '-1.09%',
#   '8.677M',
#   '1.594M',
#   '2.673B',
#   '24.30',
#   ''],
#  ['MQ',
#   'Marqeta, Inc.',
#   '4.9100',
#   '-0.0200',
#   '-0.41%',
#   '8.665M',
#   '5.671M',
#   '2.654B',
#   'N/A',
#   ''],
#  ['EBAY',
#   'eBay Inc.',
#   '45.06',
#   '-0.56',
#   '-1.23%',
#   '8.591M',
#   '4.714M',
#   '24.095B',
#   '43.33',
#   ''],
#  ['AVTR',
#   'Avantor, Inc.',
#   '19.95',
#   '+0.05',
#   '+0.25%',
#   '8.567M',
#   '6.18M',
#   '13.468B',
#   '21.92',
#   ''],
#  ['LYG',
#   'Lloyds Banking Group plc',
#   '2.2700',
#   '-0.0200',
#   '-0.87%',
#   '8.565M',
#   '11.211M',
#   '37.12B',
#   '5.54',
#   ''],
#  ['BRK-B',
#   'Berkshire Hathaway Inc.',
#   '338.31',
#   '-1.51',
#   '-0.44%',
#   '8.487M',
#   '3.322M',
#   '739.566B',
#   '100.99',
#   ''],
#  ['PAA',
#   'Plains All American Pipeline, L.P.',
#   '13.36',
#   '+0.01',
#   '+0.07%',
#   '8.473M',
#   '3.659M',
#   '9.33B',
#   '8.79',
#   ''],
#  ['UPS',
#   'United Parcel Service, Inc.',
#   '178.58',
#   '-0.42',
#   '-0.23%',
#   '8.469M',
#   '3.242M',
#   '153.38B',
#   '14.45',
#   ''],
#  ['SYF',
#   'Synchrony Financial',
#   '32.90',
#   '-0.54',
#   '-1.61%',
#   '8.462M',
#   '5.947M',
#   '14.1B',
#   '5.74',
#   ''],
#  ['INCY',
#   'Incyte Corporation',
#   '63.23',
#   '+0.65',
#   '+1.04%',
#   '8.44M',
#   '1.908M',
#   '14.106B',
#   '43.01',
#   ''],
#  ['TJX',
#   'The TJX Companies, Inc.',
#   '81.26',
#   '-0.22',
#   '-0.27%',
#   '8.394M',
#   '4.717M',
#   '93.387B',
#   '25.08',
#   ''],
#  ['UAA',
#   'Under Armour, Inc.',
#   '7.83',
#   '+0.02',
#   '+0.26%',
#   '8.315M',
#   '6.91M',
#   '3.342B',
#   '9.32',
#   ''],
#  ['PPL',
#   'PPL Corporation',
#   '26.99',
#   '-0.02',
#   '-0.07%',
#   '8.313M',
#   '4.993M',
#   '19.893B',
#   '27.54',
#   ''],
#  ['TEF',
#   'Telefónica, S.A.',
#   '3.8600',
#   '-0.1300',
#   '-3.26%',
#   '8.265M',
#   '1.002M',
#   '22.797B',
#   '14.85',
#   ''],
#  ['QS',
#   'QuantumScape Corporation',
#   '7.62',
#   '-0.27',
#   '-3.42%',
#   '8.255M',
#   '4.782M',
#   '3.381B',
#   'N/A',
#   ''],
#  ['NCNO',
#   'nCino, Inc.',
#   '31.69',
#   '+6.23',
#   '+24.47%',
#   '8.206M',
#   '982,903',
#   '3.557B',
#   'N/A',
#   ''],
#  ['AUR',
#   'Aurora Innovation, Inc.',
#   '2.2500',
#   '+0.0500',
#   '+2.27%',
#   '8.2M',
#   '2.343M',
#   '2.656B',
#   'N/A',
#   ''],
#  ['UPST',
#   'Upstart Holdings, Inc.',
#   '37.24',
#   '-0.46',
#   '-1.22%',
#   '8.142M',
#   '8.351M',
#   '3.079B',
#   'N/A',
#   ''],
#  ['DNB',
#   'Dun & Bradstreet Holdings, Inc.',
#   '11.71',
#   '+0.08',
#   '+0.69%',
#   '8.141M',
#   '2.807M',
#   '5.145B',
#   'N/A',
#   ''],
#  ['JWN',
#   'Nordstrom, Inc.',
#   '19.06',
#   '-0.31',
#   '-1.60%',
#   '8.009M',
#   '5.175M',
#   '3.078B',
#   '173.27',
#   ''],
#  ['TGTX',
#   'TG Therapeutics, Inc.',
#   '25.67',
#   '-0.81',
#   '-3.06%',
#   '7.992M',
#   '4.225M',
#   '3.835B',
#   'N/A',
#   ''],
#  ['CFLT',
#   'Confluent, Inc.',
#   '34.69',
#   '+0.20',
#   '+0.58%',
#   '7.961M',
#   '4.001M',
#   '10.273B',
#   'N/A',
#   ''],
#  ['BEKE',
#   'KE Holdings Inc.',
#   '16.98',
#   '-0.10',
#   '-0.59%',
#   '7.941M',
#   '7.513M',
#   '21.137B',
#   '73.83',
#   ''],
#  [],
#  ['IVZ',
#   'Invesco Ltd.',
#   '16.78',
#   '-0.12',
#   '-0.71%',
#   '7.933M',
#   '4.781M',
#   '7.688B',
#   '12.16',
#   ''],
#  ['BILI',
#   'Bilibili Inc.',
#   '17.47',
#   '-0.83',
#   '-4.54%',
#   '7.933M',
#   '5.161M',
#   '7.421B',
#   'N/A',
#   ''],
#  ['MGM',
#   'MGM Resorts International',
#   '42.64',
#   '-1.08',
#   '-2.47%',
#   '7.93M',
#   '4.355M',
#   '15.512B',
#   '8.90',
#   ''],
#  ['BAX',
#   'Baxter International Inc.',
#   '45.36',
#   '+0.90',
#   '+2.02%',
#   '7.918M',
#   '5.57M',
#   '22.945B',
#   'N/A',
#   ''],
#  ['BBIO',
#   'BridgeBio Pharma, Inc.',
#   '15.01',
#   '-0.51',
#   '-3.29%',
#   '7.913M',
#   '2.197M',
#   '2.409B',
#   'N/A',
#   ''],
#  ['BLDR',
#   'Builders FirstSource, Inc.',
#   '121.41',
#   '-1.60',
#   '-1.30%',
#   '7.892M',
#   '2.486M',
#   '15.54B',
#   '7.72',
#   ''],
#  ['DD',
#   'DuPont de Nemours, Inc.',
#   '69.41',
#   '-0.30',
#   '-0.43%',
#   '7.877M',
#   '3.33M',
#   '31.86B',
#   '31.84',
#   ''],
#  ['WCC',
#   'WESCO International, Inc.',
#   '168.05',
#   '-0.62',
#   '-0.37%',
#   '7.823M',
#   '786,966',
#   '8.616B',
#   '10.80',
#   ''],
#  ['BA',
#   'The Boeing Company',
#   '219.99',
#   '+0.58',
#   '+0.26%',
#   '7.804M',
#   '5.418M',
#   '132.345B',
#   'N/A',
#   ''],
#  ['MTG',
#   'MGIC Investment Corporation',
#   '15.30',
#   '-0.09',
#   '-0.58%',
#   '7.78M',
#   '2.348M',
#   '4.385B',
#   '5.50',
#   ''],
#  ['VRT',
#   'Vertiv Holdings Co',
#   '22.54',
#   '-0.06',
#   '-0.27%',
#   '7.714M',
#   '4.63M',
#   '8.559B',
#   '72.71',
#   ''],
#  ['UNH',
#   'UnitedHealth Group Incorporated',
#   '458.49',
#   '-7.40',
#   '-1.59%',
#   '7.699M',
#   '3.307M',
#   '426.869B',
#   '20.96',
#   ''],
#  ['CVE',
#   'Cenovus Energy Inc.',
#   '16.65',
#   '-0.31',
#   '-1.83%',
#   '7.697M',
#   '7.866M',
#   '31.749B',
#   '8.12',
#   ''],
#  ['MNST',
#   'Monster Beverage Corporation',
#   '58.45',
#   '-0.35',
#   '-0.60%',
#   '7.692M',
#   '4.128M',
#   '61.18B',
#   '47.91',
#   ''],
#  ['OKE',
#   'ONEOK, Inc.',
#   '60.95',
#   '-0.16',
#   '-0.26%',
#   '7.633M',
#   '3.021M',
#   '27.272B',
#   '11.48',
#   ''],
#  ['CSGP',
#   'CoStar Group, Inc.',
#   '84.14',
#   '+0.07',
#   '+0.08%',
#   '7.616M',
#   '1.909M',
#   '34.374B',
#   '92.46',
#   ''],
#  ['VICI',
#   'VICI Properties Inc.',
#   '32.34',
#   '-0.20',
#   '-0.61%',
#   '7.541M',
#   '4.789M',
#   '32.477B',
#   '22.62',
#   ''],
#  ['IBM',
#   'International Business Machines Corporation',
#   '137.48',
#   '-0.92',
#   '-0.66%',
#   '7.474M',
#   '4.381M',
#   '124.838B',
#   '61.37',
#   ''],
#  ['NDAQ',
#   'Nasdaq, Inc.',
#   '51.22',
#   '-1.05',
#   '-2.01%',
#   '7.422M',
#   '2.996M',
#   '25.137B',
#   '22.27',
#   ''],
#  ['STLD',
#   'Steel Dynamics, Inc.',
#   '102.53',
#   '-3.43',
#   '-3.24%',
#   '7.402M',
#   '1.752M',
#   '17.331B',
#   '5.42',
#   ''],
#  ['CL',
#   'Colgate-Palmolive Company',
#   '77.78',
#   '+0.98',
#   '+1.28%',
#   '7.369M',
#   '5.102M',
#   '64.524B',
#   '40.72',
#   ''],
#  ['LI',
#   'Li Auto Inc.',
#   '34.41',
#   '-0.05',
#   '-0.15%',
#   '7.251M',
#   '7.156M',
#   '33.676B',
#   'N/A',
#   ''],
#  ['FTCH',
#   'Farfetch Limited',
#   '5.75',
#   '-0.07',
#   '-1.20%',
#   '7.246M',
#   '12.509M',
#   '2.274B',
#   'N/A',
#   ''],
#  ['SAN',
#   'Banco Santander, S.A.',
#   '3.4900',
#   '-0.0100',
#   '-0.29%',
#   '7.202M',
#   '3.668M',
#   '57.361B',
#   '5.92',
#   ''],
#  ['ETRN',
#   'Equitrans Midstream Corporation',
#   '9.42',
#   '+0.04',
#   '+0.43%',
#   '7.187M',
#   '7.696M',
#   '4.081B',
#   'N/A',
#   ''],
#  [],
#  ['KSS',
#   "Kohl's Corporation",
#   '23.07',
#   '-0.65',
#   '-2.74%',
#   '7.179M',
#   '5.314M',
#   '2.551B',
#   'N/A',
#   ''],
#  ['CX',
#   'CEMEX, S.A.B. de C.V.',
#   '7.20',
#   '-0.10',
#   '-1.37%',
#   '7.172M',
#   '6.339M',
#   '10.58B',
#   '18.95',
#   ''],
#  ['PEAK',
#   'Healthpeak Properties, Inc.',
#   '20.67',
#   '-0.09',
#   '-0.43%',
#   '7.156M',
#   '4.568M',
#   '11.306B',
#   '20.47',
#   ''],
#  ['VKTX',
#   'Viking Therapeutics, Inc.',
#   '21.08',
#   '-1.38',
#   '-6.14%',
#   '7.128M',
#   '4.854M',
#   '2.105B',
#   'N/A',
#   ''],
#  ['APP',
#   'AppLovin Corporation',
#   '23.97',
#   '+0.76',
#   '+3.27%',
#   '7.12M',
#   '2.945M',
#   '8.339B',
#   'N/A',
#   ''],
#  ['IP',
#   'International Paper Company',
#   '31.98',
#   '+0.17',
#   '+0.53%',
#   '7.1M',
#   '3.17M',
#   '11.099B',
#   '7.06',
#   ''],
#  ['STT',
#   'State Street Corporation',
#   '73.77',
#   '-0.88',
#   '-1.18%',
#   '7.082M',
#   '2.75M',
#   '24.658B',
#   '10.33',
#   ''],
#  ['ASX',
#   'ASE Technology Holding Co., Ltd.',
#   '8.85',
#   '-0.09',
#   '-1.01%',
#   '6.981M',
#   '5.175M',
#   '19.03B',
#   '11.20',
#   ''],
#  ['NOV',
#   'NOV Inc.',
#   '15.59',
#   '-0.26',
#   '-1.64%',
#   '6.962M',
#   '4.991M',
#   '6.138B',
#   '18.56',
#   ''],
#  ['X',
#   'United States Steel Corporation',
#   '23.41',
#   '-0.45',
#   '-1.89%',
#   '6.948M',
#   '6.884M',
#   '5.301B',
#   '3.38',
#   ''],
#  ['ABNB',
#   'Airbnb, Inc.',
#   '128.68',
#   '+0.83',
#   '+0.65%',
#   '6.894M',
#   '6.407M',
#   '81.101B',
#   '41.64',
#   ''],
#  ['ADI',
#   'Analog Devices, Inc.',
#   '188.36',
#   '-1.30',
#   '-0.69%',
#   '6.889M',
#   '3.458M',
#   '94.447B',
#   '26.76',
#   ''],
#  ['FE',
#   'FirstEnergy Corp.',
#   '39.07',
#   '-0.04',
#   '-0.10%',
#   '6.888M',
#   '4.007M',
#   '22.381B',
#   '55.03',
#   ''],
#  ['LOW',
#   "Lowe's Companies, Inc.",
#   '217.08',
#   '-1.85',
#   '-0.85%',
#   '6.874M',
#   '2.854M',
#   '127.205B',
#   '20.83',
#   ''],
#  ['BP',
#   'BP p.l.c.',
#   '35.35',
#   '-0.03',
#   '-0.08%',
#   '6.859M',
#   '8.443M',
#   '103.034B',
#   '4.32',
#   ''],
#  ['AVGO',
#   'Broadcom Inc.',
#   '868.11',
#   '-15.32',
#   '-1.73%',
#   '6.83M',
#   '2.774M',
#   '358.256B',
#   '27.26',
#   ''],
#  ['EXEL',
#   'Exelixis, Inc.',
#   '19.09',
#   '-0.01',
#   '-0.05%',
#   '6.814M',
#   '2.786M',
#   '6.216B',
#   '40.62',
#   ''],
#  ['UAL',
#   'United Airlines Holdings, Inc.',
#   '53.50',
#   '-0.08',
#   '-0.15%',
#   '6.81M',
#   '7.074M',
#   '17.546B',
#   '9.11',
#   ''],
#  ['GGB',
#   'Gerdau S.A.',
#   '5.35',
#   '-0.02',
#   '-0.37%',
#   '6.778M',
#   '6.698M',
#   '9.352B',
#   '4.02',
#   ''],
#  ['AMGN',
#   'Amgen Inc.',
#   '229.66',
#   '+1.22',
#   '+0.53%',
#   '6.765M',
#   '2.323M',
#   '122.714B',
#   '15.60',
#   ''],
#  ['COTY',
#   'Coty Inc.',
#   '12.44',
#   '-0.01',
#   '-0.08%',
#   '6.695M',
#   '5.064M',
#   '10.609B',
#   '65.47',
#   ''],
#  ['RRC',
#   'Range Resources Corporation',
#   '28.49',
#   '+0.76',
#   '+2.74%',
#   '6.673M',
#   '4.162M',
#   '6.874B',
#   '3.35',
#   ''],
#  ['CNP',
#   'CenterPoint Energy, Inc.',
#   '29.18',
#   '-0.09',
#   '-0.31%',
#   '6.643M',
#   '3.737M',
#   '18.413B',
#   '23.16',
#   ''],
#  ['EW',
#   'Edwards Lifesciences Corporation',
#   '91.94',
#   '+0.65',
#   '+0.71%',
#   '6.598M',
#   '2.752M',
#   '55.736B',
#   '37.84',
#   ''],
#  ['LXP',
#   'LXP Industrial Trust',
#   '10.32',
#   '0.00',
#   '0.00%',
#   '6.597M',
#   '2.313M',
#   '3.028B',
#   '27.16',
#   ''],
#  [],
#  ['SNOW',
#   'Snowflake Inc.',
#   '184.18',
#   '-6.80',
#   '-3.56%',
#   '6.59M',
#   '5.974M',
#   '60.024B',
#   'N/A',
#   ''],
#  ['GT',
#   'The Goodyear Tire & Rubber Company',
#   '13.57',
#   '-0.72',
#   '-5.04%',
#   '6.533M',
#   '5.205M',
#   '3.846B',
#   '678.50',
#   ''],
#  ['VST',
#   'Vistra Corp.',
#   '25.06',
#   '-0.27',
#   '-1.07%',
#   '6.532M',
#   '3.249M',
#   '9.348B',
#   'N/A',
#   ''],
#  ['FAST',
#   'Fastenal Company',
#   '56.58',
#   '+0.34',
#   '+0.60%',
#   '6.525M',
#   '3.11M',
#   '32.31B',
#   '29.16',
#   ''],
#  ['BBY',
#   'Best Buy Co., Inc.',
#   '79.79',
#   '+0.81',
#   '+1.03%',
#   '6.435M',
#   '2.377M',
#   '17.411B',
#   '13.50',
#   ''],
#  ['PK',
#   'Park Hotels & Resorts Inc.',
#   '13.06',
#   '-0.08',
#   '-0.61%',
#   '6.421M',
#   '3.552M',
#   '2.898B',
#   '11.98',
#   ''],
#  ['FI',
#   'Fiserv, Inc.',
#   '119.96',
#   '-0.39',
#   '-0.32%',
#   '6.42M',
#   '3.799M',
#   '74.053B',
#   '31.82',
#   ''],
#  ['VIPS',
#   'Vipshop Holdings Limited',
#   '17.79',
#   '-0.54',
#   '-2.95%',
#   '6.415M',
#   '5.558M',
#   '10.017B',
#   '10.78',
#   ''],
#  ['PAAS',
#   'Pan American Silver Corp.',
#   '15.37',
#   '+0.26',
#   '+1.72%',
#   '6.411M',
#   '4.617M',
#   '5.601B',
#   'N/A',
#   ''],
#  ['SHEL',
#   'Shell plc',
#   '60.35',
#   '-0.33',
#   '-0.54%',
#   '6.411M',
#   '4.759M',
#   '205.923B',
#   '5.00',
#   ''],
#  ['DHR',
#   'Danaher Corporation',
#   '241.80',
#   '-1.71',
#   '-0.70%',
#   '6.401M',
#   '3.171M',
#   '178.424B',
#   '26.03',
#   ''],
#  ['XEL',
#   'Xcel Energy Inc.',
#   '63.92',
#   '-0.40',
#   '-0.62%',
#   '6.373M',
#   '3.047M',
#   '35.179B',
#   '19.79',
#   ''],
#  ['CRWD',
#   'CrowdStrike Holdings, Inc.',
#   '155.14',
#   '-4.67',
#   '-2.92%',
#   '6.352M',
#   '4.022M',
#   '36.785B',
#   'N/A',
#   ''],
#  ['DHI',
#   'D.R. Horton, Inc.',
#   '116.40',
#   '+0.99',
#   '+0.86%',
#   '6.319M',
#   '3.008M',
#   '39.701B',
#   '7.86',
#   ''],
#  ['ETN',
#   'Eaton Corporation plc',
#   '191.26',
#   '-5.63',
#   '-2.86%',
#   '6.249M',
#   '2.104M',
#   '76.236B',
#   '29.84',
#   ''],
#  ['IPG',
#   'The Interpublic Group of Companies, Inc.',
#   '40.04',
#   '-0.55',
#   '-1.36%',
#   '6.234M',
#   '4.805M',
#   '15.457B',
#   '17.41',
#   ''],
#  ['MMM',
#   '3M Company',
#   '104.54',
#   '+0.73',
#   '+0.70%',
#   '6.197M',
#   '3.441M',
#   '57.672B',
#   '10.80',
#   ''],
#  ['PLTK',
#   'Playtika Holding Corp.',
#   '11.38',
#   '-0.10',
#   '-0.87%',
#   '6.194M',
#   '1.244M',
#   '4.162B',
#   '15.59',
#   ''],
#  ['IBN',
#   'ICICI Bank Limited',
#   '22.87',
#   '0.00',
#   '0.00%',
#   '6.173M',
#   '4.18M',
#   '79.987B',
#   '19.72',
#   ''],
#  ['KOS',
#   'Kosmos Energy Ltd.',
#   '6.21',
#   '-0.05',
#   '-0.80%',
#   '6.148M',
#   '4.967M',
#   '2.856B',
#   '9.70',
#   ''],
#  ['JNPR',
#   'Juniper Networks, Inc.',
#   '32.47',
#   '+0.03',
#   '+0.09%',
#   '6.114M',
#   '3.948M',
#   '10.442B',
#   '21.36',
#   ''],
#  ['EOG',
#   'EOG Resources, Inc.',
#   '113.41',
#   '+1.71',
#   '+1.53%',
#   '6.114M',
#   '3.459M',
#   '66.329B',
#   '7.09',
#   ''],
#  ['FIS',
#   'Fidelity National Information Services, Inc.',
#   '54.78',
#   '+0.73',
#   '+1.35%',
#   '6.077M',
#   '5.386M',
#   '32.454B',
#   'N/A',
#   ''],
#  ['RITM',
#   'Rithm Capital Corp.',
#   '9.30',
#   '-0.05',
#   '-0.53%',
#   '6.03M',
#   '3.956M',
#   '4.492B',
#   '16.61',
#   ''],
#  ['MPLX',
#   'MPLX LP',
#   '34.07',
#   '+0.17',
#   '+0.50%',
#   '5.961M',
#   '1.721M',
#   '34.11B',
#   '8.78',
#   ''],
#  [],
#  ['ROIV',
#   'Roivant Sciences Ltd.',
#   '9.65',
#   '-0.27',
#   '-2.72%',
#   '5.96M',
#   '3.143M',
#   '7.319B',
#   'N/A',
#   ''],
#  ['ALLY',
#   'Ally Financial Inc.',
#   '28.37',
#   '-0.31',
#   '-1.08%',
#   '5.951M',
#   '5.069M',
#   '8.534B',
#   '6.92',
#   ''],
#  ['GSK',
#   'GSK plc',
#   '35.15',
#   '-0.12',
#   '-0.34%',
#   '5.945M',
#   '2.878M',
#   '71.97B',
#   '12.74',
#   ''],
#  ['ZTO',
#   'ZTO Express (Cayman) Inc.',
#   '27.46',
#   '-0.50',
#   '-1.79%',
#   '5.93M',
#   '2.763M',
#   '22.52B',
#   '20.96',
#   ''],
#  ['DFS',
#   'Discover Financial Services',
#   '115.32',
#   '-1.94',
#   '-1.65%',
#   '5.918M',
#   '2.057M',
#   '29.285B',
#   '7.76',
#   ''],
#  ['MA',
#   'Mastercard Incorporated',
#   '376.53',
#   '-2.51',
#   '-0.66%',
#   '5.882M',
#   '2.798M',
#   '356.811B',
#   '37.58',
#   ''],
#  ['LNC',
#   'Lincoln National Corporation',
#   '24.37',
#   '-0.07',
#   '-0.29%',
#   '5.881M',
#   '3.532M',
#   '4.132B',
#   'N/A',
#   ''],
#  ['PSTG',
#   'Pure Storage, Inc.',
#   '37.74',
#   '+0.14',
#   '+0.37%',
#   '5.881M',
#   '4.925M',
#   '11.595B',
#   '164.09',
#   ''],
#  ['CF',
#   'CF Industries Holdings, Inc.',
#   '71.27',
#   '+1.19',
#   '+1.70%',
#   '5.874M',
#   '2.716M',
#   '13.898B',
#   '4.75',
#   ''],
#  ['MTCH',
#   'Match Group, Inc.',
#   '42.25',
#   '-1.05',
#   '-2.42%',
#   '5.855M',
#   '5.164M',
#   '11.765B',
#   '40.62',
#   ''],
#  ['CTSH',
#   'Cognizant Technology Solutions Corporation',
#   '65.08',
#   '+0.34',
#   '+0.53%',
#   '5.84M',
#   '3.499M',
#   '33.027B',
#   '14.53',
#   ''],
#  ['PLD',
#   'Prologis, Inc.',
#   '122.63',
#   '+0.91',
#   '+0.75%',
#   '5.837M',
#   '3.095M',
#   '113.245B',
#   '38.20',
#   ''],
#  ['AA',
#   'Alcoa Corporation',
#   '35.62',
#   '-0.35',
#   '-0.97%',
#   '5.813M',
#   '4.447M',
#   '6.355B',
#   'N/A',
#   ''],
#  ['ROKU',
#   'Roku, Inc.',
#   '70.69',
#   '-1.06',
#   '-1.48%',
#   '5.794M',
#   '7.749M',
#   '9.952B',
#   'N/A',
#   ''],
#  ['TECK',
#   'Teck Resources Limited',
#   '41.96',
#   '-1.32',
#   '-3.05%',
#   '5.794M',
#   '5.25M',
#   '21.573B',
#   '7.90',
#   ''],
#  ['PHM',
#   'PulteGroup, Inc.',
#   '73.51',
#   '-0.29',
#   '-0.39%',
#   '5.783M',
#   '2.877M',
#   '16.409B',
#   '6.38',
#   ''],
#  ['DOCU',
#   'DocuSign, Inc.',
#   '53.85',
#   '-0.43',
#   '-0.79%',
#   '5.773M',
#   '3.949M',
#   '10.898B',
#   'N/A',
#   ''],
#  ['SHO',
#   'Sunstone Hotel Investors, Inc.',
#   '10.03',
#   '+0.06',
#   '+0.60%',
#   '5.677M',
#   '2.159M',
#   '2.077B',
#   '27.11',
#   ''],
#  ['PACB',
#   'Pacific Biosciences of California, Inc.',
#   '12.75',
#   '-0.56',
#   '-4.21%',
#   '5.665M',
#   '3.721M',
#   '3.186B',
#   'N/A',
#   ''],
#  ['BX',
#   'Blackstone Inc.',
#   '91.13',
#   '-1.52',
#   '-1.64%',
#   '5.653M',
#   '4.165M',
#   '109.499B',
#   '115.35',
#   ''],
#  ['CNX',
#   'CNX Resources Corporation',
#   '17.35',
#   '+0.10',
#   '+0.58%',
#   '5.631M',
#   '2.885M',
#   '2.873B',
#   '2.31',
#   ''],
#  ['CNC',
#   'Centene Corporation',
#   '65.66',
#   '-0.46',
#   '-0.70%',
#   '5.625M',
#   '3.442M',
#   '36.032B',
#   '24.23',
#   ''],
#  ['ISEE',
#   'IVERIC bio, Inc.',
#   '38.69',
#   '+0.26',
#   '+0.68%',
#   '5.603M',
#   '3.756M',
#   '5.338B',
#   'N/A',
#   ''],
#  ['AFL',
#   'Aflac Incorporated',
#   '69.43',
#   '-0.33',
#   '-0.47%',
#   '5.588M',
#   '2.344M',
#   '41.951B',
#   '9.88',
#   ''],
#  ['ARRY',
#   'Array Technologies, Inc.',
#   '21.21',
#   '-0.88',
#   '-3.98%',
#   '5.583M',
#   '4.355M',
#   '3.2B',
#   '424.20',
#   ''],
#  [],
#  ['SUZ',
#   'Suzano S.A.',
#   '10.01',
#   '+0.01',
#   '+0.10%',
#   '5.564M',
#   '1.552M',
#   '13.023B',
#   '3.46',
#   ''],
#  ['AEO',
#   'American Eagle Outfitters, Inc.',
#   '11.74',
#   '-0.18',
#   '-1.51%',
#   '5.554M',
#   '4.427M',
#   '2.318B',
#   '20.24',
#   ''],
#  ['WDC',
#   'Western Digital Corporation',
#   '40.47',
#   '-0.61',
#   '-1.48%',
#   '5.541M',
#   '3.867M',
#   '12.948B',
#   'N/A',
#   ''],
#  ['ADM',
#   'Archer-Daniels-Midland Company',
#   '75.48',
#   '+0.92',
#   '+1.23%',
#   '5.53M',
#   '2.754M',
#   '41.109B',
#   '9.47',
#   ''],
#  ['EMR',
#   'Emerson Electric Co.',
#   '87.41',
#   '-0.62',
#   '-0.70%',
#   '5.523M',
#   '3.227M',
#   '49.955B',
#   '17.73',
#   ''],
#  ['MRNA',
#   'Moderna, Inc.',
#   '128.73',
#   '-1.25',
#   '-0.96%',
#   '5.5M',
#   '3.305M',
#   '49.073B',
#   '10.75',
#   ''],
#  ['CVBF',
#   'CVB Financial Corp.',
#   '14.80',
#   '+0.17',
#   '+1.16%',
#   '5.495M',
#   '1.655M',
#   '2.061B',
#   '8.31',
#   ''],
#  ['CLVT',
#   'Clarivate Plc',
#   '9.09',
#   '-0.10',
#   '-1.09%',
#   '5.463M',
#   '5.402M',
#   '6.143B',
#   'N/A',
#   ''],
#  ['NI',
#   'NiSource Inc.',
#   '27.38',
#   '+0.04',
#   '+0.15%',
#   '5.456M',
#   '3.756M',
#   '11.31B',
#   '18.63',
#   ''],
#  ['GEHC',
#   'GE HealthCare Technologies Inc.',
#   '78.65',
#   '-0.45',
#   '-0.57%',
#   '5.391M',
#   '2.719M',
#   '35.76B',
#   '21.03',
#   ''],
#  ['GIS',
#   'General Mills, Inc.',
#   '80.71',
#   '0.00',
#   '0.00%',
#   '5.349M',
#   '3.13M',
#   '47.405B',
#   '17.43',
#   ''],
#  ['XRAY',
#   'DENTSPLY SIRONA Inc.',
#   '39.73',
#   '+1.34',
#   '+3.49%',
#   '5.337M',
#   '1.834M',
#   '8.442B',
#   'N/A',
#   ''],
#  ['PEG',
#   'Public Service Enterprise Group Incorporated',
#   '62.54',
#   '+0.28',
#   '+0.45%',
#   '5.333M',
#   '2.464M',
#   '31.205B',
#   '13.45',
#   ''],
#  ['AEP',
#   'American Electric Power Company, Inc.',
#   '84.93',
#   '+0.05',
#   '+0.06%',
#   '5.317M',
#   '2.674M',
#   '43.721B',
#   '22.06',
#   ''],
#  ['DIDIY',
#   'DiDi Global Inc.',
#   '2.9700',
#   '-0.0300',
#   '-1.00%',
#   '5.315M',
#   '7.105M',
#   '14.433B',
#   'N/A',
#   ''],
#  ['VIAV',
#   'Viavi Solutions Inc.',
#   '10.65',
#   '+0.18',
#   '+1.72%',
#   '5.31M',
#   '1.783M',
#   '2.369B',
#   '56.05',
#   ''],
#  ['HUM',
#   'Humana Inc.',
#   '445.65',
#   '-18.20',
#   '-3.92%',
#   '5.301M',
#   '1.071M',
#   '55.682B',
#   '18.09',
#   ''],
#  ['ZION',
#   'Zions Bancorporation, National Association',
#   '28.63',
#   '-0.35',
#   '-1.21%',
#   '5.291M',
#   '6.594M',
#   '4.24B',
#   '4.89',
#   ''],
#  ['AGL',
#   'agilon health, inc.',
#   '17.36',
#   '-1.35',
#   '-7.22%',
#   '5.283M',
#   '3.74M',
#   '7.202B',
#   'N/A',
#   ''],
#  ['ACN',
#   'Accenture plc',
#   '319.54',
#   '-4.23',
#   '-1.31%',
#   '5.266M',
#   '2.723M',
#   '201.962B',
#   '29.86',
#   ''],
#  ['CTLT',
#   'Catalent, Inc.',
#   '44.11',
#   '+0.52',
#   '+1.19%',
#   '5.265M',
#   '4.806M',
#   '7.952B',
#   '191.78',
#   ''],
#  ['CAT',
#   'Caterpillar Inc.',
#   '245.27',
#   '-2.40',
#   '-0.97%',
#   '5.261M',
#   '3.222M',
#   '126.644B',
#   '18.14',
#   ''],
#  ['EL',
#   'The Estée Lauder Companies Inc.',
#   '203.95',
#   '+4.54',
#   '+2.28%',
#   '5.235M',
#   '2.19M',
#   '72.894B',
#   '67.09',
#   ''],
#  ['SITC',
#   'SITE Centers Corp.',
#   '13.36',
#   '+0.16',
#   '+1.21%',
#   '5.212M',
#   '1.979M',
#   '2.798B',
#   '18.05',
#   ''],
#  ['PSNY',
#   'Polestar Automotive Holding UK PLC',
#   '4.0300',
#   '+0.1000',
#   '+2.54%',
#   '5.166M',
#   '2.794M',
#   '8.503B',
#   'N/A',
#   ''],
#  [],
#  ['CRDO',
#   'Credo Technology Group Holding Ltd',
#   '18.03',
#   '+0.31',
#   '+1.75%',
#   '5.136M',
#   '2.045M',
#   '2.679B',
#   'N/A',
#   ''],
#  ['CAH',
#   'Cardinal Health, Inc.',
#   '91.25',
#   '+2.09',
#   '+2.34%',
#   '5.134M',
#   '2.229M',
#   '23.232B',
#   '52.44',
#   ''],
#  ['W',
#   'Wayfair Inc.',
#   '55.28',
#   '+1.94',
#   '+3.64%',
#   '5.112M',
#   '5.449M',
#   '6.207B',
#   'N/A',
#   ''],
#  ['OGN',
#   'Organon & Co.',
#   '20.91',
#   '-0.01',
#   '-0.05%',
#   '5.098M',
#   '1.992M',
#   '5.333B',
#   '7.16',
#   ''],
#  ['STNE',
#   'StoneCo Ltd.',
#   '13.52',
#   '+0.31',
#   '+2.35%',
#   '5.051M',
#   '5.342M',
#   '4.231B',
#   '1,352.00',
#   ''],
#  ['IFF',
#   'International Flavors & Fragrances Inc.',
#   '80.35',
#   '+0.85',
#   '+1.07%',
#   '5.051M',
#   '1.808M',
#   '20.497B',
#   'N/A',
#   ''],
#  ['CPG',
#   'Crescent Point Energy Corp.',
#   '6.77',
#   '+0.05',
#   '+0.74%',
#   '5.039M',
#   '4.28M',
#   '3.695B',
#   '9.40',
#   ''],
#  ['MRVI',
#   'Maravai LifeSciences Holdings, Inc.',
#   '13.78',
#   '+0.38',
#   '+2.84%',
#   '5.033M',
#   '2.548M',
#   '3.459B',
#   '11.98',
#   ''],
#  ['FTI',
#   'TechnipFMC plc',
#   '14.72',
#   '+0.01',
#   '+0.07%',
#   '5.031M',
#   '4.995M',
#   '6.5B',
#   'N/A',
#   ''],
#  ['STM',
#   'STMicroelectronics N.V.',
#   '49.99',
#   '+0.14',
#   '+0.28%',
#   '5.019M',
#   '3.537M',
#   '44.997B',
#   '11.11',
#   ''],
#  ['PAGS',
#   'PagSeguro Digital Ltd.',
#   '10.21',
#   '-0.07',
#   '-0.68%',
#   '5.015M',
#   '4.4M',
#   '3.311B',
#   '10.75',
#   ''],
#  ['CDNS',
#   'Cadence Design Systems, Inc.',
#   '235.84',
#   '-1.93',
#   '-0.81%',
#   '5.007M',
#   '1.869M',
#   '64.31B',
#   '75.11',
#   ''],
#  ['HON',
#   'Honeywell International Inc.',
#   '202.97',
#   '-0.76',
#   '-0.37%',
#   '5.006M',
#   '2.414M',
#   '135.112B',
#   '26.39',
#   ''],
#  ['NVST',
#   'Envista Holdings Corporation',
#   '33.47',
#   '+0.84',
#   '+2.57%',
#   '5.005M',
#   '2.087M',
#   '5.479B',
#   '26.78',
#   ''],
#  ['EQH',
#   'Equitable Holdings, Inc.',
#   '26.43',
#   '-0.27',
#   '-1.01%',
#   '5M',
#   '3.419M',
#   '9.411B',
#   '7.38',
#   '']]

# %%
browser.quit()

# %%
# Create DataFrame  
stock_df = pd.DataFrame(stock_list, columns = column)
stock_df = stock_df.drop_duplicates()

# %%
# Print DataFrame to check
stock_df
# Out:
#     Symbol                          Name Price (Intraday) Change % Change  \
# 0     None                          None             None   None     None
# 1     TSLA                   Tesla, Inc.           260.54  +4.64   +1.81%
# 2     INTC             Intel Corporation            36.37  +0.55   +1.54%
# 3     SOFI       SoFi Technologies, Inc.             8.60  -0.95   -9.95%
# 4     AAPL                    Apple Inc.           184.92  -1.09   -0.59%
# ..     ...                           ...              ...    ...      ...
# 453   PAGS        PagSeguro Digital Ltd.            10.21  -0.07   -0.68%
# 454   CDNS  Cadence Design Systems, Inc.           235.84  -1.93   -0.81%
# 455    HON  Honeywell International Inc.           202.97  -0.76   -0.37%
# 456   NVST  Envista Holdings Corporation            33.47  +0.84   +2.57%
# 457    EQH      Equitable Holdings, Inc.            26.43  -0.27   -1.01%
#
#        Volume Avg Vol (3 month) Market Cap PE Ratio (TTM) 52 Week Range
# 0        None              None       None           None          None
# 1    167.916M          134.541M   825.782B          75.08
# 2     110.24M           45.625M   151.699B            N/A
# 3    107.557M            49.16M     8.092B            N/A
# 4    101.256M           58.332M     2.909T          31.34
# ..        ...               ...        ...            ...           ...
# 453    5.015M              4.4M     3.311B          10.75
# 454    5.007M            1.869M     64.31B          75.11
# 455    5.006M            2.414M   135.112B          26.39
# 456    5.005M            2.087M     5.479B          26.78
# 457        5M            3.419M     9.411B           7.38
#
# [416 rows x 10 columns]

# %%
# Cleaning Data Frame
stock_df = stock_df.drop(0)
stock_df = stock_df.reset_index(drop = True)
stock_df = stock_df.drop(columns = '52 Week Range')

stock_df.head()
# Out:
#   Symbol                     Name Price (Intraday) Change % Change    Volume  \
# 0   TSLA              Tesla, Inc.           260.54  +4.64   +1.81%  167.916M
# 1   INTC        Intel Corporation            36.37  +0.55   +1.54%   110.24M
# 2   SOFI  SoFi Technologies, Inc.             8.60  -0.95   -9.95%  107.557M
# 3   AAPL               Apple Inc.           184.92  -1.09   -0.59%  101.256M
# 4   RIVN  Rivian Automotive, Inc.            14.88  -0.36   -2.36%    92.23M
#
#   Avg Vol (3 month) Market Cap PE Ratio (TTM)
# 0          134.541M   825.782B          75.08
# 1           45.625M   151.699B            N/A
# 2            49.16M     8.092B            N/A
# 3           58.332M     2.909T          31.34
# 4           25.096M    13.977B            N/A

# %%
# Check DataTypes
stock_df.dtypes
# Out:
# Symbol               object
# Name                 object
# Price (Intraday)     object
# Change               object
# % Change             object
# Volume               object
# Avg Vol (3 month)    object
# Market Cap           object
# PE Ratio (TTM)       object
# dtype: object

# %%
# Remove % sign to allow for conversion to float
stock_df['% Change'] = stock_df['% Change'].str.replace('%','')

# Convert to float
stock_df[['Price (Intraday)','Change','% Change']] = stock_df[['Price (Intraday)','Change','% Change']].astype(float)
stock_df.head()
# Out:
#   Symbol                     Name  Price (Intraday)  Change  % Change  \
# 0   TSLA              Tesla, Inc.            260.54    4.64      1.81
# 1   INTC        Intel Corporation             36.37    0.55      1.54
# 2   SOFI  SoFi Technologies, Inc.              8.60   -0.95     -9.95
# 3   AAPL               Apple Inc.            184.92   -1.09     -0.59
# 4   RIVN  Rivian Automotive, Inc.             14.88   -0.36     -2.36
#
#      Volume Avg Vol (3 month) Market Cap PE Ratio (TTM)
# 0  167.916M          134.541M   825.782B          75.08
# 1   110.24M           45.625M   151.699B            N/A
# 2  107.557M            49.16M     8.092B            N/A
# 3  101.256M           58.332M     2.909T          31.34
# 4    92.23M           25.096M    13.977B            N/A

# %%
# Check conversion to float
stock_df.dtypes
# Out:
# Symbol                object
# Name                  object
# Price (Intraday)     float64
# Change               float64
# % Change             float64
# Volume                object
# Avg Vol (3 month)     object
# Market Cap            object
# PE Ratio (TTM)        object
# dtype: object

# %%
# Separate Billion dollar Market Cap from Trillion Dollar Market Cap
billion_MC =stock_df[stock_df['Market Cap'].str.contains("B")==True]
trillion_MC = stock_df[stock_df['Market Cap'].str.contains("T")==True]

# Convert Market Cap to Floats 
billion_MC['Market Cap'] = billion_MC['Market Cap'].str.replace('B','')
billion_MC['PE Ratio (TTM)'] = billion_MC['PE Ratio (TTM)'].str.replace(',','')
billion_MC['Market Cap'] = billion_MC['Market Cap'].astype(float)

trillion_MC['Market Cap'] = trillion_MC['Market Cap'].str.replace('T','')
trillion_MC['PE Ratio (TTM)'] = trillion_MC['PE Ratio (TTM)'].str.replace(',','')
trillion_MC['Market Cap'] = trillion_MC['Market Cap'].astype(float)
# Out:
# /var/folders/mr/nzdp38cj3cz3b0gcgyvws4c40000gp/T/ipykernel_32648/3226244765.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billion_MC['Market Cap'] = billion_MC['Market Cap'].str.replace('B','')
# /var/folders/mr/nzdp38cj3cz3b0gcgyvws4c40000gp/T/ipykernel_32648/3226244765.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billion_MC['PE Ratio (TTM)'] = billion_MC['PE Ratio (TTM)'].str.replace(',','')
# /var/folders/mr/nzdp38cj3cz3b0gcgyvws4c40000gp/T/ipykernel_32648/3226244765.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billion_MC['Market Cap'] = billion_MC['Market Cap'].astype(float)
# /var/folders/mr/nzdp38cj3cz3b0gcgyvws4c40000gp/T/ipykernel_32648/3226244765.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trillion_MC['Market Cap'] = trillion_MC['Market Cap'].str.replace('T','')
# /var/folders/mr/nzdp38cj3cz3b0gcgyvws4c40000gp/T/ipykernel_32648/3226244765.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trillion_MC['PE Ratio (TTM)'] = trillion_MC['PE Ratio (TTM)'].str.replace(',','')
# /var/folders/mr/nzdp38cj3cz3b0gcgyvws4c40000gp/T/ipykernel_32648/3226244765.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trillion_MC['Market Cap'] = trillion_MC['Market Cap'].astype(float)

# %%
# Rename Columns for Clarity
billion_MC = billion_MC.rename(columns = {'Market Cap': 'Market Cap (Billions)'})
trillion_MC = trillion_MC.rename(columns = {'Market Cap': 'Market Cap (Trillions)'})

# %%
# Calculate how many companies have N/A PE ratios
billion_PE = billion_MC.groupby('PE Ratio (TTM)').count()
billion_PE['Name']

trillion_PE = trillion_MC.groupby('PE Ratio (TTM)').count()
trillion_PE['Name']
# Out:
# PE Ratio (TTM)
# 222.35    1
# 27.63     1
# 27.76     1
# 306.07    1
# 31.34     1
# 37.59     1
# Name: Name, dtype: int64

# %%
# Create New Dataset without 'N/A' in PE Ratio 
billion_with_PE = billion_MC.loc[(billion_MC['PE Ratio (TTM)'] != 'N/A')]

# Convert billions PE ratio to float
billion_with_PE['PE Ratio (TTM)'] = billion_with_PE['PE Ratio (TTM)'].astype(float)
billion_with_PE = billion_with_PE.reset_index(drop = True)
billion_with_PE.head()
# Out:
# /var/folders/mr/nzdp38cj3cz3b0gcgyvws4c40000gp/T/ipykernel_32648/2025838986.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billion_with_PE['PE Ratio (TTM)'] = billion_with_PE['PE Ratio (TTM)'].astype(float)
#   Symbol                          Name  Price (Intraday)  Change  % Change  \
# 0   TSLA                   Tesla, Inc.            260.54    4.64      1.81
# 1    AMD  Advanced Micro Devices, Inc.            120.08   -4.16     -3.35
# 2   DISH      DISH Network Corporation              6.47    0.23      3.69
# 3      F            Ford Motor Company             14.42   -0.03     -0.21
# 4    PFE                   Pfizer Inc.             40.06    0.31      0.78
#
#      Volume Avg Vol (3 month)  Market Cap (Billions)  PE Ratio (TTM)
# 0  167.916M          134.541M                825.782           75.08
# 1   82.007M           68.773M                193.372          667.11
# 2   79.289M           12.497M                  3.446            1.91
# 3   75.398M           61.555M                 57.691           19.75
# 4   60.339M           24.457M                226.151            7.90

# %%
trillion_MC['PE Ratio (TTM)'] = trillion_MC['PE Ratio (TTM)'].astype(float)
trillion_MC = trillion_MC.reset_index(drop = True)
trillion_MC.head()
# Out:
#   Symbol                   Name  Price (Intraday)  Change  % Change    Volume  \
# 0   AAPL             Apple Inc.            184.92   -1.09     -0.59  101.256M
# 1   AMZN       Amazon.com, Inc.            125.49   -1.62     -1.27   84.247M
# 2   NVDA     NVIDIA Corporation            426.92    0.39      0.09   65.571M
# 3   GOOG          Alphabet Inc.            124.06   -1.73     -1.38   56.699M
# 4   MSFT  Microsoft Corporation            346.62   -1.48     -0.43   46.552M
#
#   Avg Vol (3 month)  Market Cap (Trillions)  PE Ratio (TTM)
# 0           58.332M                   2.909           31.34
# 1           62.096M                   1.288          306.07
# 2            47.72M                   1.054          222.35
# 3           26.554M                   1.571           27.63
# 4           28.589M                   2.577           37.59

# %%
trillion_MC
# Out:
#   Symbol                   Name  Price (Intraday)  Change  % Change    Volume  \
# 0   AAPL             Apple Inc.            184.92   -1.09     -0.59  101.256M
# 1   AMZN       Amazon.com, Inc.            125.49   -1.62     -1.27   84.247M
# 2   NVDA     NVIDIA Corporation            426.92    0.39      0.09   65.571M
# 3   GOOG          Alphabet Inc.            124.06   -1.73     -1.38   56.699M
# 4   MSFT  Microsoft Corporation            346.62   -1.48     -0.43   46.552M
# 5  GOOGL          Alphabet Inc.            123.53   -1.56     -1.25   45.536M
#
#   Avg Vol (3 month)  Market Cap (Trillions)  PE Ratio (TTM)
# 0           58.332M                   2.909           31.34
# 1           62.096M                   1.288          306.07
# 2            47.72M                   1.054          222.35
# 3           26.554M                   1.571           27.63
# 4           28.589M                   2.577           37.59
# 5           34.295M                   1.572           27.76

# %%
import hvplot.pandas as hv

trillion_PE_Ratio_Map = trillion_MC.hvplot.points(
    "Price (Intraday)",
    "PE Ratio (TTM)",
    color = "Name",
    hover_cols = ['Symbol','Name'],
    legend = False
)
# $ pip install mplcursors

# trillion_MC.plot.scatter(x = 'Price (Intraday)', y = 'PE Ratio (TTM)')
# mplcursors.cursor(hover = True)

trillion_PE_Ratio_Map
# Out:
# :Points   [Price (Intraday),PE Ratio (TTM)]   (Name,Symbol)

# %%
# Display the stocks with Billion Dollar Market Cap in regards to Price and PE ratio
billion_PE_Ratio_Map = billion_with_PE.hvplot.points(
    "Price (Intraday)",
    "PE Ratio (TTM)",
    color = "Name",
    hover_cols = ['Symbol','Name'],
    legend = False
    
)


billion_PE_Ratio_Map
# Out:
# :Points   [Price (Intraday),PE Ratio (TTM)]   (Name,Symbol)

# %%
# Separate Stocks that didn't have a PE ratio

no_PE = billion_MC.loc[(billion_MC['PE Ratio (TTM)'] == 'N/A')]
no_PE = no_PE.reset_index(drop = True)
# Out:
#   Symbol                        Name  Price (Intraday)  Change  % Change  \
# 0   INTC           Intel Corporation             36.37    0.55      1.54
# 1   SOFI     SoFi Technologies, Inc.              8.60   -0.95     -9.95
# 2   RIVN     Rivian Automotive, Inc.             14.88   -0.36     -2.36
# 3   PLTR  Palantir Technologies Inc.             16.30   -0.30     -1.81
# 4    NIO                    NIO Inc.              9.40   -0.39     -3.98
#
#      Volume Avg Vol (3 month)  Market Cap (Billions) PE Ratio (TTM)
# 0   110.24M           45.625M                151.699            N/A
# 1  107.557M            49.16M                  8.092            N/A
# 2    92.23M           25.096M                 13.977            N/A
# 3   90.696M           65.051M                 34.531            N/A
# 4     81.4M           50.885M                 16.785            N/A
